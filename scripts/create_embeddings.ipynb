# %% [markdown]
# # Create embeddings.
#
# ### Description
# This pipeline creates sentence embeddings and downloads them to the data/ folder in our shared workfolder. The process consists of loading the dataset that includes transcriptions, labels and topic changes and create embeddings representations per podcast. Due to the size of the dataset (~4000 videos) We save each tensor of embeddings to a specific folder for later processing. Results are saved in the "./data/dataset_name/pre-trained model/video_id.pt" folder. We use two different model architectures to calculate the embeddings, SBERT and Universal Sentence encoder. Both have different pre trained models that can also be selected.
#
#  Parameters:
#  - dataset_name: Name of the dataset to be loaded and processed.
#  - model_name: Type of model to create the sentence embeddings.
#  - pre_trained_model: Pre trained model to use in the sentence embeddings process
#  - dim_redux_method: What type of dimensionality reduction process to use to create the sentence embeddings from the token embeddings.
#  - print_debug: Print a message everytime an embedding is created.

# %%
#@title Imported Packages and Libraries
# !pip install nlp --quiet
# !pip install transformers --quiet
# !pip install datasets --quiet
# !pip install -U sentence-transformers --quiet

from collections import Counter
import numpy as np
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from nlp import load_dataset

import seaborn as sns
from pprint import pprint 

# Utilites
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
from numpy.linalg import norm
from numpy import dot
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import csv
import time
import torch
from datetime import datetime
from torch._C import NoneType
from transformers import AutoTokenizer, AutoModel

# JSON
import json

# Embeddings
from transformers import BertTokenizer, TFBertModel
import sklearn as sk
import nltk
from nltk.data import find

# Pandas CSV processing
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Formatting options for float number in numpy
float_formatter = "{:.4f}".format
np.set_printoptions(formatter={'float_kind':float_formatter})

from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/W266/project/nlp_podcast_segmentation/" #@param ["/content/drive/MyDrive/W266/project/nlp_podcast_segmentation/", "other"] {allow-input: true}
# Out:
#      |████████████████████████████████| 1.7 MB 4.3 MB/s
#      |████████████████████████████████| 212 kB 66.4 MB/s
#      |████████████████████████████████| 5.8 MB 3.8 MB/s
#      |████████████████████████████████| 7.6 MB 52.8 MB/s
#      |████████████████████████████████| 182 kB 83.0 MB/s
#      |████████████████████████████████| 451 kB 4.1 MB/s
#      |████████████████████████████████| 132 kB 61.2 MB/s
#      |████████████████████████████████| 127 kB 71.3 MB/s
#      |████████████████████████████████| 85 kB 2.4 MB/s
#      |████████████████████████████████| 1.3 MB 14.7 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done
# Mounted at /content/drive

# %%
#@title Choose parameters
# Choose parameters

dataset_name = "YouTube/yt_scripts_segments_split_n3_111422.csv" #@param ["AMIDataset", "YouTube/yt_scripts_segments_yt_simple_110922.csv", "YouTube/yt_scripts_segments_split_n5_111422.csv", "YouTube/yt_scripts_segments_split_n3_111422.csv","YouTube/yt_small_spacy_dev.csv", "YouTube/yt_scripts_segments_spacy_111022.csv", "YouTube/yt_scripts_segments_split_n5_111422_subset10.csv","YouTube/yt_scripts_segments_split_n10_112922.csv"]
model_name = "SBERT" #@param ["SBERT", "Universal Sentence Encoder"]
pre_trained_model =   "all-mpnet-base-v2" #@param ["all-mpnet-base-v2","stsb-mpnet-base-v2", "all-MiniLM-L6-v2", "multi-qa-mpnet-base-dot-v1", "nli-bert-large-max-pooling", "https://tfhub.dev/google/universal-sentence-encoder/4", "https://tfhub.dev/google/universal-sentence-encoder-large/5", "/content/drive/MyDrive/W266/project/nlp_podcast_segmentation/scripts/ricardo/use/"]
dim_redux_method = 'meanpooling' #@param ["meanpooling", "maxpooling"]
print_debug = "Yes" #@param ["Yes", "No"]
if model_name == "Universal Sentence Encoder":
  pre_trained_model_url = pre_trained_model
  pre_trained_model = str(pre_trained_model.split("/")[-2]) + "-" + str(pre_trained_model.split("/")[-1]) 

filename = ""
if len(dataset_name.split("/")) > 1:
  if dataset_name.split("/")[-2] == "YouTube":
    filename = dataset_name.split("/")[-1]
    dataset_name = dataset_name.split("/")[-2]
    print("Filename:                  " + filename)
print("Dataset:                   " + dataset_name)
print("Model:                     " + model_name)
print("Pre-trained Model:         " + pre_trained_model)
print("Dimensionality Redyction:  " + dim_redux_method)

# Define loading functions

#Remove adjacent topic changes
def clean_adj_topic(topic_list):
  '''
  Removes the second topic change from two neighboring topic changes
  Example: [0,1,1,0,1,1,1,0,1] would be cleaned to [0,1,0,0,1,0,1,0,1]
  '''

  idx = 1
  N = len(topic_list)
  clean_list = topic_list.copy()

  while(idx < N):
    if(clean_list[idx] == 1 and clean_list[idx-1] == 1):
      clean_list[idx] = 0

    idx += 1

  return clean_list

# average_sentences
# Calculate average sentences
def average_sentences(topic_list):
  '''
  Counts the number of sentences between topics
  input: topic labels
  returns: average number of sentences between topics
  '''

  idx = 0
  N = len(topic_list)
  sentence_counts = []
  count = 0

  while(idx < N):
    if(topic_list[idx] == 1):
      sentence_counts.append(count)
      count = 0

    count += 1
    idx += 1

  
  if len(sentence_counts) == 0:
    return 0
    
  return sum(sentence_counts) / len(sentence_counts)

# evaluate_pk
# Evaluates PK
def evaluate_pk(pred, act, k=5):
  idx = k
  miss_count = 0
  measurement = 0

  while (idx+k) < len(act):
    topic_change_pred = False
    topic_change_act = False

    #Checking if there is a topic change - not including the first index
    if sum(pred[idx-(k-1):idx+k]) >= 1:
      topic_change_pred = True
    if sum(act[idx-(k-1):idx+k]) >= 1:
      topic_change_act = True

    if topic_change_pred != topic_change_act:
      miss_count += 1.0

    measurement += 1.0
    idx += 1

  # print(miss_count)
  # print(measurement)
  pk = miss_count/measurement

  return pk

# evaluate_pk
# Evaluates WD
def evaluate_wd(pred, act, k=5):
  idx = k
  N = len(act)
  count = 0

  while (idx+k) < N:
    # print(pred[idx-(k-1):idx+k])
    sum_pred = sum(pred[idx-(k):idx+k])
    sum_act = sum(act[idx-(k):idx+k])

    #adds a count only if the number of boundaries is greater than 0
    if abs(sum_pred - sum_act) > 0:
      count += 1

    idx += 1

  # print(miss_count)
  # print(measurement)
  wd = (1/(N-k))*count

  return wd

# get_meeting_sentences:
# retrieves specific sentences from the transcripts_list
def get_meeting_sentences(embedding_name="", S_list=[], T_list=[], Y_list=[], transcripts_list=[]):
  for transcript_idx, transcript in enumerate(transcripts_list):
    if transcript == embedding_name:
      return S_list[transcript_idx], T_list[transcript_idx], Y_list[transcript_idx], transcript

# cos_sim:
# Calculates cosine similarity between two vectors
def cos_sim(a,b):
  return dot(a, b)/(norm(a)*norm(b))

# estimate_total:
# Estimates total ETA to finish embeddings
def estimate_total(S_list, done_embeddings, emb_speed):
  # Inputs: S_list, and list of done embeddings, embedding speed
  # Returns ETA for completion.
  total_ETA = 0
  total_words_to_embed = 0
  for idx, sentences_to_embed in enumerate(S_list):
    transcript_to_do = transcripts_list[idx]
    if transcript_to_do in done_embeddings:
      continue
    else:
      for sentence_to_embed in sentences_to_embed:
        total_words_to_embed = total_words_to_embed + len(sentence_to_embed.split())
  total_ETA = total_words_to_embed/emb_speed
  return total_ETA

# get_done_embeddings:
# Searches all embeddings done in a folder.
# Inputs: Embeddings Path
# Returns List of transcript names that have embeddings stored in file
def get_done_embeddings(embeddings_path):
  embeddings_path = embeddings_path
  done_embeddings = []
  embedding_name = ""
  for embeddingsPath, embeddingsDname, embedddingsFname in os.walk(os.path.join(embeddings_path)):
    for embeddings_name in embedddingsFname:
      if embeddings_name.split(".")[-1] == "pt" or embeddings_name.split(".")[-1] == "npy":
        embeddings_name = embeddings_name.replace(".pt","")
        embeddings_name = embeddings_name.replace(".npy","")
        if embeddings_name not in transcripts_list:
          continue
        done_embeddings.append(embeddings_name)
    break
  return done_embeddings

# get_done_metrics:
# Searches all metrics done in a csv file.
def get_done_metrics(metric_results_filename_path="",
                     Y_hat_list_filename_path="", 
                     T_hat_list_filename_path="",
                     sims_list_filename_path=""):
  with open(metric_results_filename_path, 'r+', encoding='UTF8', newline='') as f:
    done_metrics = []
    PK_metrics = []
    WD_metrics = []
    Y_hat_list = []
    T_hat_list = []
    csv_reader = csv.reader(f, delimiter=',')
    line_count = 0
    for row_idx, row in enumerate(csv_reader):
      done_metrics.append(row[1])
      PK_metrics.append(row[2])
      WD_metrics.append(row[3])
  Y_hat_list = np.load(Y_hat_list_filename_path,allow_pickle=True).tolist()
  T_hat_list = np.load(T_hat_list_filename_path,allow_pickle=True).tolist()
  sims_list = np.load(sims_list_filename_path,allow_pickle=True).tolist()
  return done_metrics, PK_metrics, WD_metrics, Y_hat_list, T_hat_list, sims_list

# load_ami_dataset:
# Loads Transcripts from .transcripts/ folder and converts them into
# S:                list of M utterances S = {S_1,..., S_M}
# T:                Underlying topic structure Ti ∈ [Sj , Sk]
# Y:                Label sequence Y = {y1,.., yM} yi is binary indicates whether the utterance Si is the start of a new topic segment
# S_List:           List of S_i (utterances) for the i-th transcript or meeting
# T_List:           List of T_i (Topic changes tuples) for the i-th transcript or meeting
# Y_List:           List of Y_i (Topic changes flat) for the i-th transcript or meeting
# transcripts_list: List of transcript names. Meetings or video_id.
def load_ami_dataset(transcript_path=""):

  # Initiate variables
  S_list=[]
  T_list = []
  Y_list = []
  transcripts_list=[]
  meeting_transcripts=[]

  # Reads JSON from Folder
  try:
    transcripts = []
    meeting_transcripts = []
    transcripts_list = []
    for transcriptPath, transcriptDname, transcriptFname in os.walk(os.path.join(transcripts_path)):
      for transcript_name in transcriptFname:
        transcripts_list.append(transcript_name.replace(".json",""))
        transcript_path = os.path.join(transcripts_path,transcript_name)
        with open(transcript_path) as f:
          data = json.load(f)
        meeting_transcripts.append(data)
  except Exception as error:
    print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " ---  Error Loading JSON files - " + str(error))
    return S_list, T_list, Y_list, transcripts_list

  # Process data set to return Main Variables
  try:
    S = []                
    S_list = []            
    T = []
    T_list = []            
    Y = []            
    Y_list = []
    W_count = []
    W_count_list = []
    W_T_count = []
    W_T_count_list = []
    W_M_count = []

    T_start = 0
    T_prev = 0
    T_end = 0
    idx_prev = 0
    vocabulary = set()
    sentence_greater = []

    for meeting_idx, meeting_transcript in enumerate(meeting_transcripts):
      # Change this to get one big vector
      S = []
      T = []
      Y = []
      W_count = []
      W_T_count = []
      T_start = 0
      T_prev = 0
      T_end = 0
      idx_prev = 0
      meeting_word_count = 0

      transcript_id = transcripts_list[meeting_idx]
      # print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " ---  " + str(transcript_id) + " - Start Process")
      # Remove above to get one big vector
      for topics_idx, topics in enumerate(meeting_transcript):
        topic_word_count = 0
        for sentence_idx, sentence in enumerate(topics['sentences']):
          # Generate S Vector
          sentence_text = sentence['text']
          sentence_text = sentence_text.replace(" . ",". ")
          sentence_text = sentence_text.replace(" . ",". ")
          sentence_text = sentence_text.replace("[gap]","")
          sentence_text = sentence_text.replace("[vocalsound]","")
          sentence_text = sentence_text.replace("[disfmarker]","")
          sentence_text = sentence_text.replace("[transformerror]"," ")
          sentence_word_count = len(sentence_text.split())
          topic_word_count = topic_word_count + sentence_word_count
          meeting_word_count = meeting_word_count + sentence_word_count
          W_count.append(sentence_word_count)
          # print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " ---  " + str(transcript_id) + " - Topic: " + str(topics['topic_idx']) + " Sentence: " + str(sentence_idx) + " Word Count: " + str(sentence_word_count))

          # Check if Sentence over 512 Words
          if sentence_word_count > 512:
            print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " ---  Error wordcount over 512 " + str(transcript_id) + " - Topic: "  + str(topics_idx) + " title: " + str(topics['topic_idx']) + " Sentence: " + str(sentence_idx) + " Word Count: " + str(sentence_word_count))
            sentence_greater.append(sentence_text)
          S.append(sentence_text)
          # Generate T initial and T end 
          if sentence_idx == 0:
            T_start = T_prev
            Y.append(1)
          else:
            Y.append(0)

          # Create Vocabulary set
          for word in sentence_text.split():
            vocabulary.add(word)
        T_end = sentence_idx + T_prev
        T.append((T_start,T_end))
        T_prev = T_end + 1
        W_T_count.append(topic_word_count)
        # print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " ---  " + str(transcript_id) + " - Word count per topic: " + str(topic_word_count) + " Total Sentences: " + str(len(S)) + " Total sentence words: " + str(len(W_count)) + " Total topics: " + str(len(T)))
      S_list.append(S)
      T_list.append(T)
      Y_list.append(Y)
      W_count_list.append(W_count)
      W_T_count_list.append(W_T_count)
      W_M_count.append(meeting_word_count)
      # print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " ---  " + str(transcript_id) + " - Total Sentences: " + str(len(S)) + " Total Sentence word count: " + str(len(W_count)) + " Total topics: " + str(len(T)) + " Total topics word_count: " + str(len(W_T_count)))
    # test_sentenece = 25
    # print(Y_list[test_sentenece])
    # print(len(S_list[test_sentenece][0]))
    # print(T_list[test_sentenece])
    # print(sentence_greater)

    # print("Total Topics for meeting 25: " + str(len(meeting_transcripts[25])))
    # print("Example of meeting: " + str(meeting_transcripts[25]))
    # print("Meeting name: " + str(transcripts_list[25]))
    # print(len(meeting_transcripts[:1]))
    # print(len(meeting_transcripts[0]))

    # index_test = 115
    # print(len(S[index_test].split()))
    # print(W_count[index_test])
    # print(len(meeting_transcripts))
    # print(len(W_M_count))

    # index_test = 25
    for meeting_idx, meeting_transcript in enumerate(meeting_transcripts):
      meeting_word_count = 0
      transcript_id = transcripts_list[meeting_idx]
      # if meeting_idx != index_test:
      #   continue
      for topics_idx, topics in enumerate(meeting_transcript):
        for sentence_idx, sentence in enumerate(topics['sentences']):
          sentence_text = sentence['text']
          sentence_text = sentence_text.replace(" . ",". ")
          sentence_text = sentence_text.replace(" . ",". ")
          sentence_text = sentence_text.replace("[gap]","")
          sentence_text = sentence_text.replace("[vocalsound]","")
          sentence_text = sentence_text.replace("[disfmarker]","")
          sentence_text = sentence_text.replace("[transformerror]"," ")
          sentence_word_count = len(sentence_text.split())
          meeting_word_count = meeting_word_count + sentence_word_count
      # print(meeting_word_count)
    # print(W_M_count[index_test])
  except Exception as error:
    print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " ---  Error Processing AMI Dataset - " + str(error))
    return S_list, T_list, Y_list, transcripts_list

  return S_list, T_list, Y_list, transcripts_list

# load_youtube_dataset:
# Loads csvs from .YouTube/ folder and converts them into
# S:                list of M utterances S = {S_1,..., S_M}
# T:                Underlying topic structure Ti ∈ [Sj , Sk]
# Y:                Label sequence Y = {y1,.., yM} yi is binary indicates whether the utterance Si is the start of a new topic segment
# S_List:           List of S_i (utterances) for the i-th transcript or meeting
# T_List:           List of T_i (Topic changes tuples) for the i-th transcript or meeting
# Y_List:           List of Y_i (Topic changes flat) for the i-th transcript or meeting
# transcripts_list: List of transcript names. Meetings or video_id.
def load_youtube_dataset(dataset_path="", filename=""):
  # Initiate variables
  S_list=[]
  T_list = []
  Y_list = []
  transcripts_list=[]
  meeting_transcripts=[]

  # Reads CSV from Folder
  try:
    # filename = "yt_small_spacy_dev.csv"
    # filename = "yt_scripts_segments_yt_simple_110922.csv"
    csv_path = os.path.join(dataset_path,filename)
    yt_pods = pd.read_pickle(csv_path)
    # print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " --- Loaded CSV: " + str(csv_path))
  except Exception as error:
    print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " ---  Error Loading csv from YouTube Dataset - " + str(error))
    return S_list, T_list, Y_list, transcripts_list

  # Process data set to return Main Variables
  try:
    for video_idx, video_id in enumerate(yt_pods["Video_Id"]):
      transcripts_list.append(video_id)

    for sentences_idx, sentences in enumerate(yt_pods["Sentence_Word_Lists"]):
      S=[]
      for sentence_idx, sentence in enumerate(sentences):
        sentence_text = sentence[0]
        S.append(sentence_text)
      S_size = len(S)
      S_list.append(S)

    for transcript_labels_tuple_idx, transcript_labels_tuple in enumerate(yt_pods["Transition_Labels_Tuple"]):
      T_list.append(transcript_labels_tuple)

    for transcript_labels_idx, transcript_labels in enumerate(yt_pods["Transition_Labels"]):
      Y_list.append(transcript_labels)
      
    # print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " --- Processed Video: " + str(video_id) + " - Sentences: " + str(S_size))
  except Exception as error:
    print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + " --- Error processing Video: " + str(video_id) + " - Index: " +str(sentences_idx) + " - " + str(error))
    return S_list, T_list, Y_list, transcripts_list
  
  return S_list, T_list, Y_list, transcripts_list

# load_process_dataset:
# Process all datasets, and returns main variables and
# transcripts, daset path
def load_process_dataset(dataset_name="", filename=""):
  S_list=[]
  T_list=[]
  Y_list=[]
  W_count_list=[]
  meeting_transcripts = []
  transcripts_list = []
  dataset_path = ""
  transcripts_path = ""
  embeddings_path = ""
  dataset_path = os.path.join(path,'data/' + dataset_name + "/")
  transcripts_path = os.path.join(dataset_path,'transcripts/')
  if dataset_name == "AMIDataset":
    S_list, T_list, Y_list, transcripts_list = load_ami_dataset(transcripts_path)
  elif dataset_name == "YouTube":
    S_list, T_list, Y_list, transcripts_list = load_youtube_dataset(dataset_path=dataset_path,filename=filename)
  return (S_list, T_list, Y_list, W_count_list), (meeting_transcripts, transcripts_list), (dataset_path, transcripts_path)
# Out:
# Filename:                  yt_scripts_segments_split_n3_111422.csv
# Dataset:                   YouTube
# Model:                     SBERT
# Pre-trained Model:         all-mpnet-base-v2
# Dimensionality Redyction:  meanpooling

# %%
#@title Load Dataset
(S_list, T_list, Y_list, W_count_list), (meeting_transcripts, transcripts_list), (dataset_path, transcripts_path) = load_process_dataset(dataset_name = dataset_name, filename = filename)

# Print Test
index_test = 3
print("\n")
print("Transcripts path:            " + str(transcripts_path))
print("Dataset path:                " + str(dataset_path))
print("Numb of transcripts S_list:  " + str(len(S_list)))
print("Numb of Topics T_list:       " + str(len(T_list)))
print("Numb of Outputs Y_list:      " + str(len(Y_list)))
print("Transcripts name:            " + str(transcripts_list[index_test]))
print("Numb of sentences in Test    " + str(len(S_list[index_test])))
print("Numb of topics in Test       " + str(len(T_list[index_test])))
print("Numb of Outputs in Test      " + str(len(Y_list[index_test])))
# Out:
# Transcripts path:            /content/drive/MyDrive/W266/project/nlp_podcast_segmentation/data/YouTube/transcripts/
# Dataset path:                /content/drive/MyDrive/W266/project/nlp_podcast_segmentation/data/YouTube/
# Numb of transcripts S_list:  3731
# Numb of Topics T_list:       3731
# Numb of Outputs Y_list:      3731
# Transcripts name:            M5IzFvBQ-Zo
# Numb of sentences in Test    904
# Numb of topics in Test       6
# Numb of Outputs in Test      904

# %%
#@title Load pre-trained model

print("Loading Model: " + str(model_name) + " Pretrained model name: " + str(pre_trained_model))
if model_name == "SBERT":

  # Define specific function of SBERT

  def max_pooling(model_output, attention_mask):
    # Max Pooling - Take the max value over time for every dimension. 
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    token_embeddings[input_mask_expanded == 0] = -1e9  # Set padding tokens to large negative value
    return torch.max(token_embeddings, 1)[0]

  def mean_pooling(model_output, attention_mask):
    #Mean Pooling - Take attention mask into account for correct averaging
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask

  # Load model from HuggingFace Hub (Sentence Bert Max Pooling)
  tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/' + pre_trained_model)
  model = AutoModel.from_pretrained('sentence-transformers/' + pre_trained_model)

elif model_name == "Universal Sentence Encoder":
  model = hub.load(pre_trained_model_url)
  print ("module %s loaded" % pre_trained_model)
  def use_embed(input):
    return model(input)

print("Loaded Model: " + str(model_name) + " Pretrained model name: " + str(pre_trained_model))
# Out:
# Loading Model: SBERT Pretrained model name: all-mpnet-base-v2
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Loaded Model: SBERT Pretrained model name: all-mpnet-base-v2

# %%
#@title Create embeddins per transription

# Prepare Sentence and get embeddings for ALL transcript

# Prepare Variables
done_embeddings = []
sentence_embeddings_list = []
pre_trained_model_fullname = str(pre_trained_model + '-' + dim_redux_method)

# Define Embeddings path depending on Dataset
embeddings_path = os.path.join(dataset_path,'embeddings/', str(pre_trained_model_fullname + '/'))
if dataset_name == "YouTube":
  filename_folder = filename.split(".")[-2]
  embeddings_path = os.path.join(dataset_path,'embeddings/', str(filename_folder), str(pre_trained_model_fullname + '/'))

# Check if embeddings folder exists if not create it
if not os.path.exists(embeddings_path):
   os.makedirs(embeddings_path)
   print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + 
         " - " + str(pre_trained_model_fullname) + 
         " - Embedding folder not found. New folder created")

# List all embeddings in folder embeddings_path
done_embeddings = get_done_embeddings(embeddings_path)

# Run for all transcripts
for transcripts_list_idx, sentences in enumerate(S_list):

  # Start Process
  embedding_name = transcripts_list[transcripts_list_idx]
  
  if embedding_name in done_embeddings : # or embedding_name != "ES2013a":
    if print_debug == "Yes":
      print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + 
            " - " + str(pre_trained_model_fullname) + 
            " - " + str(embedding_name) + 
            " - done: " + str(transcripts_list_idx +1) + " of: " + str(len(S_list)) +
            " - Skipping embedding, already Done.")
    continue
  else:
    # Embeddings
    start_time = time.time()
    if print_debug == "Yes":
      print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + 
            " - " + str(pre_trained_model_fullname) + 
            " - " + str(embedding_name) + 
            " - done: " + str(transcripts_list_idx +1) + " of: " + str(len(S_list)) +
            " - Start -  Embeddings: " + str(len(sentences)))

    # Compute token embeddings
    if model_name == "SBERT":
      try:
        # Tokenize sentences
        encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt',max_length=3000)

        # Create Embedding
        with torch.no_grad():
            model_output = model(**encoded_input)
        
        # MAX or MEAN pooling
        if dim_redux_method == "maxpooling":
          sentence_embeddings = max_pooling(model_output, encoded_input['attention_mask'])
        elif dim_redux_method == "meanpooling":
          sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

        # Check if embeddings size is correct
        sentence_embeddings_size_total = sentence_embeddings.size()
        sentence_embeddings_size = sentence_embeddings_size_total[0]
        if int(sentence_embeddings_size) != len(sentences):
          print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + 
                " - " + str(pre_trained_model_fullname) + 
                " - " + str(embedding_name) + 
                " - done: " + str(transcripts_list_idx +1) + " of: " + str(len(S_list)) +
                " - ERROR on Emb Size Test: " + str(sentence_embeddings_size_total) + " != " + str(len(sentences)))
          break

        # Save tensor to file
        full_embeddings_path = os.path.join(embeddings_path, str(embedding_name + ".pt"))
        torch.save(sentence_embeddings,full_embeddings_path)

      except Exception as error:
        print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + 
              " - " + str(pre_trained_model_fullname) + 
              " - " + str(embedding_name) + 
              " - done: " + str(transcripts_list_idx +1) + " of: " + str(len(S_list)) +
              " - Error computing embedding, skipping... " + str(error))
        continue
    
    elif model_name == "Universal Sentence Encoder":
      try:

        # Create Embedding
        sentence_embeddings = use_embed(sentences)

        # Check if embeddings size is correct
        sentence_embeddings_size_total = sentence_embeddings.shape
        sentence_embeddings_size = sentence_embeddings_size_total[0]
        if int(sentence_embeddings_size) != len(sentences):
          print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + 
                " - " + str(pre_trained_model_fullname) + 
                " - " + str(embedding_name) + 
                " - done: " + str(transcripts_list_idx +1) + " of: " + str(len(S_list)) +
                " - ERROR on Emb Size Test: " + str(sentence_embeddings_size_total) + " != " + str(len(sentences)))
          break

        # Save tensor to file
        sentence_embeddings_np = sentence_embeddings.numpy()
        full_embeddings_path = os.path.join(embeddings_path, str(embedding_name + ".npy"))
        np.save(full_embeddings_path, np.asarray(sentence_embeddings_np, dtype=object))
        # one_string_tensor = tf.strings.format("{}", sentence_embeddings)
        # tf.io.write_file(full_embeddings_path, one_string_tensor)
      
      except Exception as error:
        print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + 
              " - " + str(pre_trained_model_fullname) + 
              " - " + str(embedding_name) + 
              " - done: " + str(transcripts_list_idx +1) + " of: " + str(len(S_list)) +
              " - Error computing embedding, skipping... " + str(error))
        continue

    done_embeddings.append(embedding_name)

    print(datetime.today().strftime('%Y-%m-%d %H:%M:%S') + 
          " - " + str(pre_trained_model_fullname) + 
          " - " + str(embedding_name) + 
          " - done: " + str(transcripts_list_idx +1) + " of: " + str(len(S_list)) +
          " - Emb Size: " + str(sentence_embeddings_size_total))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 2022-12-03 03:32:02 - all-mpnet-base-v2-meanpooling - VIx8a_Ywrvg - done: 258 of: 3731 - Emb Size: torch.Size([660, 768])
# 2022-12-03 03:32:02 - all-mpnet-base-v2-meanpooling - AE5Bqw3e4lQ - done: 259 of: 3731 - Start -  Embeddings: 536
# 2022-12-03 03:32:18 - all-mpnet-base-v2-meanpooling - AE5Bqw3e4lQ - done: 259 of: 3731 - Emb Size: torch.Size([536, 768])
# 2022-12-03 03:32:18 - all-mpnet-base-v2-meanpooling - 2PNNIlay4cw - done: 260 of: 3731 - Start -  Embeddings: 716
# 2022-12-03 03:32:40 - all-mpnet-base-v2-meanpooling - 2PNNIlay4cw - done: 260 of: 3731 - Emb Size: torch.Size([716, 768])
# 2022-12-03 03:32:40 - all-mpnet-base-v2-meanpooling - d_HNYsEEHlQ - done: 261 of: 3731 - Start -  Embeddings: 618
# 2022-12-03 03:32:59 - all-mpnet-base-v2-meanpooling - d_HNYsEEHlQ - done: 261 of: 3731 - Emb Size: torch.Size([618, 768])
# 2022-12-03 03:32:59 - all-mpnet-base-v2-meanpooling - wIHJtlXc0CI - done: 262 of: 3731 - Start -  Embeddings: 696
# 2022-12-03 03:33:25 - all-mpnet-base-v2-meanpooling - wIHJtlXc0CI - done: 262 of: 3731 - Emb Size: torch.Size([696, 768])
# 2022-12-03 03:33:25 - all-mpnet-base-v2-meanpooling - DGcHdJTZHVI - done: 263 of: 3731 - Start -  Embeddings: 724
# 2022-12-03 03:33:47 - all-mpnet-base-v2-meanpooling - DGcHdJTZHVI - done: 263 of: 3731 - Emb Size: torch.Size([724, 768])
# 2022-12-03 03:33:47 - all-mpnet-base-v2-meanpooling - 1b6p3bC-6MA - done: 264 of: 3731 - Start -  Embeddings: 665
# 2022-12-03 03:34:11 - all-mpnet-base-v2-meanpooling - 1b6p3bC-6MA - done: 264 of: 3731 - Emb Size: torch.Size([665, 768])
# 2022-12-03 03:34:11 - all-mpnet-base-v2-meanpooling - ttwnTwudNEM - done: 265 of: 3731 - Start -  Embeddings: 531
# 2022-12-03 03:34:28 - all-mpnet-base-v2-meanpooling - ttwnTwudNEM - done: 265 of: 3731 - Emb Size: torch.Size([531, 768])
# 2022-12-03 03:34:28 - all-mpnet-base-v2-meanpooling - BLlgrES9rIo - done: 266 of: 3731 - Start -  Embeddings: 721
# 2022-12-03 03:34:50 - all-mpnet-base-v2-meanpooling - BLlgrES9rIo - done: 266 of: 3731 - Emb Size: torch.Size([721, 768])
# 2022-12-03 03:34:50 - all-mpnet-base-v2-meanpooling - K00nH1a8qVk - done: 267 of: 3731 - Start -  Embeddings: 614
# 2022-12-03 03:35:12 - all-mpnet-base-v2-meanpooling - K00nH1a8qVk - done: 267 of: 3731 - Emb Size: torch.Size([614, 768])
# 2022-12-03 03:35:12 - all-mpnet-base-v2-meanpooling - 8YYpeM0PYB8 - done: 268 of: 3731 - Start -  Embeddings: 561
# 2022-12-03 03:35:29 - all-mpnet-base-v2-meanpooling - 8YYpeM0PYB8 - done: 268 of: 3731 - Emb Size: torch.Size([561, 768])
# 2022-12-03 03:35:29 - all-mpnet-base-v2-meanpooling - ZczAG6TVKwk - done: 269 of: 3731 - Start -  Embeddings: 445
# 2022-12-03 03:35:44 - all-mpnet-base-v2-meanpooling - ZczAG6TVKwk - done: 269 of: 3731 - Emb Size: torch.Size([445, 768])
# 2022-12-03 03:35:44 - all-mpnet-base-v2-meanpooling - SGeJxAG4mMY - done: 270 of: 3731 - Start -  Embeddings: 504
# 2022-12-03 03:36:00 - all-mpnet-base-v2-meanpooling - SGeJxAG4mMY - done: 270 of: 3731 - Emb Size: torch.Size([504, 768])
# 2022-12-03 03:36:00 - all-mpnet-base-v2-meanpooling - hsXZ0YYOZRs - done: 271 of: 3731 - Start -  Embeddings: 125
# 2022-12-03 03:36:06 - all-mpnet-base-v2-meanpooling - hsXZ0YYOZRs - done: 271 of: 3731 - Emb Size: torch.Size([125, 768])
# 2022-12-03 03:36:06 - all-mpnet-base-v2-meanpooling - pQFayYN36JQ - done: 272 of: 3731 - Start -  Embeddings: 294
# 2022-12-03 03:36:21 - all-mpnet-base-v2-meanpooling - pQFayYN36JQ - done: 272 of: 3731 - Emb Size: torch.Size([294, 768])
# 2022-12-03 03:36:21 - all-mpnet-base-v2-meanpooling - 3XLcu4hPjWM - done: 273 of: 3731 - Start -  Embeddings: 294
# 2022-12-03 03:36:36 - all-mpnet-base-v2-meanpooling - 3XLcu4hPjWM - done: 273 of: 3731 - Emb Size: torch.Size([294, 768])
# 2022-12-03 03:36:36 - all-mpnet-base-v2-meanpooling - rgLjXM-p494 - done: 274 of: 3731 - Start -  Embeddings: 292
# 2022-12-03 03:36:54 - all-mpnet-base-v2-meanpooling - rgLjXM-p494 - done: 274 of: 3731 - Emb Size: torch.Size([292, 768])
# 2022-12-03 03:36:54 - all-mpnet-base-v2-meanpooling - otkW_bsxkDc - done: 275 of: 3731 - Start -  Embeddings: 275
# 2022-12-03 03:37:09 - all-mpnet-base-v2-meanpooling - otkW_bsxkDc - done: 275 of: 3731 - Emb Size: torch.Size([275, 768])
# 2022-12-03 03:37:09 - all-mpnet-base-v2-meanpooling - AkuMN3dRzl0 - done: 276 of: 3731 - Start -  Embeddings: 107
# 2022-12-03 03:37:15 - all-mpnet-base-v2-meanpooling - AkuMN3dRzl0 - done: 276 of: 3731 - Emb Size: torch.Size([107, 768])
# 2022-12-03 03:37:15 - all-mpnet-base-v2-meanpooling - ZeGZUF_W70Q - done: 277 of: 3731 - Start -  Embeddings: 137
# 2022-12-03 03:37:23 - all-mpnet-base-v2-meanpooling - ZeGZUF_W70Q - done: 277 of: 3731 - Emb Size: torch.Size([137, 768])
# 2022-12-03 03:37:23 - all-mpnet-base-v2-meanpooling - qNI4pRDKJFg - done: 278 of: 3731 - Start -  Embeddings: 282
# 2022-12-03 03:37:37 - all-mpnet-base-v2-meanpooling - qNI4pRDKJFg - done: 278 of: 3731 - Emb Size: torch.Size([282, 768])
# 2022-12-03 03:37:37 - all-mpnet-base-v2-meanpooling - woXZw4yvW4E - done: 279 of: 3731 - Start -  Embeddings: 276
# 2022-12-03 03:37:52 - all-mpnet-base-v2-meanpooling - woXZw4yvW4E - done: 279 of: 3731 - Emb Size: torch.Size([276, 768])
# 2022-12-03 03:37:52 - all-mpnet-base-v2-meanpooling - D8NdNt5PNNo - done: 280 of: 3731 - Start -  Embeddings: 280
# 2022-12-03 03:38:07 - all-mpnet-base-v2-meanpooling - D8NdNt5PNNo - done: 280 of: 3731 - Emb Size: torch.Size([280, 768])
# 2022-12-03 03:38:07 - all-mpnet-base-v2-meanpooling - fi-ZGQYFzH0 - done: 281 of: 3731 - Start -  Embeddings: 242
# 2022-12-03 03:38:21 - all-mpnet-base-v2-meanpooling - fi-ZGQYFzH0 - done: 281 of: 3731 - Emb Size: torch.Size([242, 768])
# 2022-12-03 03:38:21 - all-mpnet-base-v2-meanpooling - CQ-NJ73ZWso - done: 282 of: 3731 - Start -  Embeddings: 278
# 2022-12-03 03:38:36 - all-mpnet-base-v2-meanpooling - CQ-NJ73ZWso - done: 282 of: 3731 - Emb Size: torch.Size([278, 768])
# 2022-12-03 03:38:36 - all-mpnet-base-v2-meanpooling - Cj2GAlswhFw - done: 283 of: 3731 - Start -  Embeddings: 96
# 2022-12-03 03:38:42 - all-mpnet-base-v2-meanpooling - Cj2GAlswhFw - done: 283 of: 3731 - Emb Size: torch.Size([96, 768])
# 2022-12-03 03:38:42 - all-mpnet-base-v2-meanpooling - GvbzRi7YvF8 - done: 284 of: 3731 - Start -  Embeddings: 124
# 2022-12-03 03:38:48 - all-mpnet-base-v2-meanpooling - GvbzRi7YvF8 - done: 284 of: 3731 - Emb Size: torch.Size([124, 768])
# 2022-12-03 03:38:48 - all-mpnet-base-v2-meanpooling - QMNQzw7fxGY - done: 285 of: 3731 - Start -  Embeddings: 294
# 2022-12-03 03:39:03 - all-mpnet-base-v2-meanpooling - QMNQzw7fxGY - done: 285 of: 3731 - Emb Size: torch.Size([294, 768])
# 2022-12-03 03:39:03 - all-mpnet-base-v2-meanpooling - xfLwfKRWDNo - done: 286 of: 3731 - Start -  Embeddings: 305
# 2022-12-03 03:39:22 - all-mpnet-base-v2-meanpooling - xfLwfKRWDNo - done: 286 of: 3731 - Emb Size: torch.Size([305, 768])
# 2022-12-03 03:39:22 - all-mpnet-base-v2-meanpooling - 3mkxYa3fEmk - done: 287 of: 3731 - Start -  Embeddings: 268
# 2022-12-03 03:39:36 - all-mpnet-base-v2-meanpooling - 3mkxYa3fEmk - done: 287 of: 3731 - Emb Size: torch.Size([268, 768])
# 2022-12-03 03:39:36 - all-mpnet-base-v2-meanpooling - 2_x6jxdMSeI - done: 288 of: 3731 - Start -  Embeddings: 275
# 2022-12-03 03:39:50 - all-mpnet-base-v2-meanpooling - 2_x6jxdMSeI - done: 288 of: 3731 - Emb Size: torch.Size([275, 768])
# 2022-12-03 03:39:50 - all-mpnet-base-v2-meanpooling - mywqKdf-NdQ - done: 289 of: 3731 - Start -  Embeddings: 280
# 2022-12-03 03:40:05 - all-mpnet-base-v2-meanpooling - mywqKdf-NdQ - done: 289 of: 3731 - Emb Size: torch.Size([280, 768])
# 2022-12-03 03:40:05 - all-mpnet-base-v2-meanpooling - hlwM3eTMV6I - done: 290 of: 3731 - Start -  Embeddings: 95
# 2022-12-03 03:40:11 - all-mpnet-base-v2-meanpooling - hlwM3eTMV6I - done: 290 of: 3731 - Emb Size: torch.Size([95, 768])
# 2022-12-03 03:40:11 - all-mpnet-base-v2-meanpooling - yEjW6WXmfAs - done: 291 of: 3731 - Start -  Embeddings: 125
# 2022-12-03 03:40:17 - all-mpnet-base-v2-meanpooling - yEjW6WXmfAs - done: 291 of: 3731 - Emb Size: torch.Size([125, 768])
# 2022-12-03 03:40:17 - all-mpnet-base-v2-meanpooling - BpWcmCh-uJ8 - done: 292 of: 3731 - Start -  Embeddings: 268
# 2022-12-03 03:40:31 - all-mpnet-base-v2-meanpooling - BpWcmCh-uJ8 - done: 292 of: 3731 - Emb Size: torch.Size([268, 768])
# 2022-12-03 03:40:31 - all-mpnet-base-v2-meanpooling - lPuiBGvovKk - done: 293 of: 3731 - Start -  Embeddings: 311
# 2022-12-03 03:40:50 - all-mpnet-base-v2-meanpooling - lPuiBGvovKk - done: 293 of: 3731 - Emb Size: torch.Size([311, 768])
# 2022-12-03 03:40:50 - all-mpnet-base-v2-meanpooling - AMrXchYaTIQ - done: 294 of: 3731 - Start -  Embeddings: 274
# 2022-12-03 03:41:04 - all-mpnet-base-v2-meanpooling - AMrXchYaTIQ - done: 294 of: 3731 - Emb Size: torch.Size([274, 768])
# 2022-12-03 03:41:04 - all-mpnet-base-v2-meanpooling - oLyFvDA4Ip4 - done: 295 of: 3731 - Start -  Embeddings: 264
# 2022-12-03 03:41:18 - all-mpnet-base-v2-meanpooling - oLyFvDA4Ip4 - done: 295 of: 3731 - Emb Size: torch.Size([264, 768])
# 2022-12-03 03:41:18 - all-mpnet-base-v2-meanpooling - HaBTVERAbv4 - done: 296 of: 3731 - Start -  Embeddings: 276
# 2022-12-03 03:41:33 - all-mpnet-base-v2-meanpooling - HaBTVERAbv4 - done: 296 of: 3731 - Emb Size: torch.Size([276, 768])
# 2022-12-03 03:41:33 - all-mpnet-base-v2-meanpooling - S1Y8G-61PZA - done: 297 of: 3731 - Start -  Embeddings: 95
# 2022-12-03 03:41:38 - all-mpnet-base-v2-meanpooling - S1Y8G-61PZA - done: 297 of: 3731 - Emb Size: torch.Size([95, 768])
# 2022-12-03 03:41:38 - all-mpnet-base-v2-meanpooling - 0plBAzNbuKo - done: 298 of: 3731 - Start -  Embeddings: 125
# 2022-12-03 03:41:44 - all-mpnet-base-v2-meanpooling - 0plBAzNbuKo - done: 298 of: 3731 - Emb Size: torch.Size([125, 768])
# 2022-12-03 03:41:44 - all-mpnet-base-v2-meanpooling - llPUHKXj7UM - done: 299 of: 3731 - Start -  Embeddings: 276
# 2022-12-03 03:42:02 - all-mpnet-base-v2-meanpooling - llPUHKXj7UM - done: 299 of: 3731 - Emb Size: torch.Size([276, 768])
# 2022-12-03 03:42:02 - all-mpnet-base-v2-meanpooling - NNXpTjmNyjk - done: 300 of: 3731 - Start -  Embeddings: 270
# 2022-12-03 03:42:16 - all-mpnet-base-v2-meanpooling - NNXpTjmNyjk - done: 300 of: 3731 - Emb Size: torch.Size([270, 768])
# 2022-12-03 03:42:16 - all-mpnet-base-v2-meanpooling - L6atn2lZeYc - done: 301 of: 3731 - Start -  Embeddings: 287
# 2022-12-03 03:42:30 - all-mpnet-base-v2-meanpooling - L6atn2lZeYc - done: 301 of: 3731 - Emb Size: torch.Size([287, 768])
# 2022-12-03 03:42:30 - all-mpnet-base-v2-meanpooling - aZXiL-azLYU - done: 302 of: 3731 - Start -  Embeddings: 277
# 2022-12-03 03:42:46 - all-mpnet-base-v2-meanpooling - aZXiL-azLYU - done: 302 of: 3731 - Emb Size: torch.Size([277, 768])
# 2022-12-03 03:42:46 - all-mpnet-base-v2-meanpooling - 7z1Or5iYZEc - done: 303 of: 3731 - Start -  Embeddings: 128
# 2022-12-03 03:42:52 - all-mpnet-base-v2-meanpooling - 7z1Or5iYZEc - done: 303 of: 3731 - Emb Size: torch.Size([128, 768])
# 2022-12-03 03:42:52 - all-mpnet-base-v2-meanpooling - FxQo5ja_J4I - done: 304 of: 3731 - Start -  Embeddings: 126
# 2022-12-03 03:42:58 - all-mpnet-base-v2-meanpooling - FxQo5ja_J4I - done: 304 of: 3731 - Emb Size: torch.Size([126, 768])
# 2022-12-03 03:42:58 - all-mpnet-base-v2-meanpooling - g3Dp9Fm9-tU - done: 305 of: 3731 - Start -  Embeddings: 292
# 2022-12-03 03:43:13 - all-mpnet-base-v2-meanpooling - g3Dp9Fm9-tU - done: 305 of: 3731 - Emb Size: torch.Size([292, 768])
# 2022-12-03 03:43:13 - all-mpnet-base-v2-meanpooling - 54oBz_2y8l4 - done: 306 of: 3731 - Start -  Embeddings: 281
# 2022-12-03 03:43:29 - all-mpnet-base-v2-meanpooling - 54oBz_2y8l4 - done: 306 of: 3731 - Emb Size: torch.Size([281, 768])
# 2022-12-03 03:43:29 - all-mpnet-base-v2-meanpooling - Jxs0q-3KUTE - done: 307 of: 3731 - Start -  Embeddings: 278
# 2022-12-03 03:43:43 - all-mpnet-base-v2-meanpooling - Jxs0q-3KUTE - done: 307 of: 3731 - Emb Size: torch.Size([278, 768])
# 2022-12-03 03:43:43 - all-mpnet-base-v2-meanpooling - nrAKJHyY3rg - done: 308 of: 3731 - Start -  Embeddings: 279
# 2022-12-03 03:43:59 - all-mpnet-base-v2-meanpooling - nrAKJHyY3rg - done: 308 of: 3731 - Emb Size: torch.Size([279, 768])
# 2022-12-03 03:43:59 - all-mpnet-base-v2-meanpooling - p_uHSrML9Rg - done: 309 of: 3731 - Start -  Embeddings: 97
# 2022-12-03 03:44:04 - all-mpnet-base-v2-meanpooling - p_uHSrML9Rg - done: 309 of: 3731 - Emb Size: torch.Size([97, 768])
# 2022-12-03 03:44:04 - all-mpnet-base-v2-meanpooling - XnHOk0dRr3M - done: 310 of: 3731 - Start -  Embeddings: 133
# 2022-12-03 03:44:11 - all-mpnet-base-v2-meanpooling - XnHOk0dRr3M - done: 310 of: 3731 - Emb Size: torch.Size([133, 768])
# 2022-12-03 03:44:11 - all-mpnet-base-v2-meanpooling - _QoaT6nXNCo - done: 311 of: 3731 - Start -  Embeddings: 301
# 2022-12-03 03:44:26 - all-mpnet-base-v2-meanpooling - _QoaT6nXNCo - done: 311 of: 3731 - Emb Size: torch.Size([301, 768])
# 2022-12-03 03:44:26 - all-mpnet-base-v2-meanpooling - XPiwyjq4Y6Q - done: 312 of: 3731 - Start -  Embeddings: 281
# 2022-12-03 03:44:41 - all-mpnet-base-v2-meanpooling - XPiwyjq4Y6Q - done: 312 of: 3731 - Emb Size: torch.Size([281, 768])
# 2022-12-03 03:44:41 - all-mpnet-base-v2-meanpooling - IohYjONoggg - done: 313 of: 3731 - Start -  Embeddings: 274
# 2022-12-03 03:44:57 - all-mpnet-base-v2-meanpooling - IohYjONoggg - done: 313 of: 3731 - Emb Size: torch.Size([274, 768])
# 2022-12-03 03:44:57 - all-mpnet-base-v2-meanpooling - Ylv08Pk4oks - done: 314 of: 3731 - Start -  Embeddings: 281
# 2022-12-03 03:45:14 - all-mpnet-base-v2-meanpooling - Ylv08Pk4oks - done: 314 of: 3731 - Emb Size: torch.Size([281, 768])
# 2022-12-03 03:45:14 - all-mpnet-base-v2-meanpooling - MMWLzE5y2G8 - done: 315 of: 3731 - Start -  Embeddings: 290
# 2022-12-03 03:45:31 - all-mpnet-base-v2-meanpooling - MMWLzE5y2G8 - done: 315 of: 3731 - Emb Size: torch.Size([290, 768])
# 2022-12-03 03:45:31 - all-mpnet-base-v2-meanpooling - CGc57fXbCoI - done: 316 of: 3731 - Start -  Embeddings: 113
# 2022-12-03 03:45:37 - all-mpnet-base-v2-meanpooling - CGc57fXbCoI - done: 316 of: 3731 - Emb Size: torch.Size([113, 768])
# 2022-12-03 03:45:37 - all-mpnet-base-v2-meanpooling - bZ-jq0seuBo - done: 317 of: 3731 - Start -  Embeddings: 111
# 2022-12-03 03:45:42 - all-mpnet-base-v2-meanpooling - bZ-jq0seuBo - done: 317 of: 3731 - Emb Size: torch.Size([111, 768])
# 2022-12-03 03:45:42 - all-mpnet-base-v2-meanpooling - pKDf4IFPmas - done: 318 of: 3731 - Start -  Embeddings: 274
# 2022-12-03 03:45:57 - all-mpnet-base-v2-meanpooling - pKDf4IFPmas - done: 318 of: 3731 - Emb Size: torch.Size([274, 768])
# 2022-12-03 03:45:57 - all-mpnet-base-v2-meanpooling - NOK3RDVytN8 - done: 319 of: 3731 - Start -  Embeddings: 312
# 2022-12-03 03:46:13 - all-mpnet-base-v2-meanpooling - NOK3RDVytN8 - done: 319 of: 3731 - Emb Size: torch.Size([312, 768])
# 2022-12-03 03:46:13 - all-mpnet-base-v2-meanpooling - Xu1RsmU3lJ0 - done: 320 of: 3731 - Start -  Embeddings: 286
# 2022-12-03 03:46:29 - all-mpnet-base-v2-meanpooling - Xu1RsmU3lJ0 - done: 320 of: 3731 - Emb Size: torch.Size([286, 768])
# 2022-12-03 03:46:29 - all-mpnet-base-v2-meanpooling - 8lQVoSh-DEo - done: 321 of: 3731 - Start -  Embeddings: 289
# 2022-12-03 03:46:44 - all-mpnet-base-v2-meanpooling - 8lQVoSh-DEo - done: 321 of: 3731 - Emb Size: torch.Size([289, 768])
# 2022-12-03 03:46:44 - all-mpnet-base-v2-meanpooling - B5DvEtZGHfU - done: 322 of: 3731 - Start -  Embeddings: 88
# 2022-12-03 03:46:49 - all-mpnet-base-v2-meanpooling - B5DvEtZGHfU - done: 322 of: 3731 - Emb Size: torch.Size([88, 768])
# 2022-12-03 03:46:49 - all-mpnet-base-v2-meanpooling - G1NHQIeiogI - done: 323 of: 3731 - Start -  Embeddings: 89
# 2022-12-03 03:46:55 - all-mpnet-base-v2-meanpooling - G1NHQIeiogI - done: 323 of: 3731 - Emb Size: torch.Size([89, 768])
# 2022-12-03 03:46:55 - all-mpnet-base-v2-meanpooling - e6_Gc9JcRqI - done: 324 of: 3731 - Start -  Embeddings: 275
# 2022-12-03 03:47:09 - all-mpnet-base-v2-meanpooling - e6_Gc9JcRqI - done: 324 of: 3731 - Emb Size: torch.Size([275, 768])
# 2022-12-03 03:47:09 - all-mpnet-base-v2-meanpooling - lqB4uq8zjTo - done: 325 of: 3731 - Start -  Embeddings: 271
# 2022-12-03 03:47:24 - all-mpnet-base-v2-meanpooling - lqB4uq8zjTo - done: 325 of: 3731 - Emb Size: torch.Size([271, 768])
# 2022-12-03 03:47:24 - all-mpnet-base-v2-meanpooling - H3goTZBTuNY - done: 326 of: 3731 - Start -  Embeddings: 303
# 2022-12-03 03:47:40 - all-mpnet-base-v2-meanpooling - H3goTZBTuNY - done: 326 of: 3731 - Emb Size: torch.Size([303, 768])
# 2022-12-03 03:47:40 - all-mpnet-base-v2-meanpooling - zeo6yAOKB8E - done: 327 of: 3731 - Start -  Embeddings: 294
# 2022-12-03 03:47:55 - all-mpnet-base-v2-meanpooling - zeo6yAOKB8E - done: 327 of: 3731 - Emb Size: torch.Size([294, 768])
# 2022-12-03 03:47:55 - all-mpnet-base-v2-meanpooling - hu01Sr4R340 - done: 328 of: 3731 - Start -  Embeddings: 283
# 2022-12-03 03:48:09 - all-mpnet-base-v2-meanpooling - hu01Sr4R340 - done: 328 of: 3731 - Emb Size: torch.Size([283, 768])
# 2022-12-03 03:48:09 - all-mpnet-base-v2-meanpooling - PSbdhBclkYA - done: 329 of: 3731 - Start -  Embeddings: 94
# 2022-12-03 03:48:15 - all-mpnet-base-v2-meanpooling - PSbdhBclkYA - done: 329 of: 3731 - Emb Size: torch.Size([94, 768])
# 2022-12-03 03:48:15 - all-mpnet-base-v2-meanpooling - x53jQgjZgRw - done: 330 of: 3731 - Start -  Embeddings: 128
# 2022-12-03 03:48:22 - all-mpnet-base-v2-meanpooling - x53jQgjZgRw - done: 330 of: 3731 - Emb Size: torch.Size([128, 768])
# 2022-12-03 03:48:22 - all-mpnet-base-v2-meanpooling - T4jPqBW8lCk - done: 331 of: 3731 - Start -  Embeddings: 283
# 2022-12-03 03:48:37 - all-mpnet-base-v2-meanpooling - T4jPqBW8lCk - done: 331 of: 3731 - Emb Size: torch.Size([283, 768])
# 2022-12-03 03:48:37 - all-mpnet-base-v2-meanpooling - ovp03Fw8u_c - done: 332 of: 3731 - Start -  Embeddings: 283
# 2022-12-03 03:48:51 - all-mpnet-base-v2-meanpooling - ovp03Fw8u_c - done: 332 of: 3731 - Emb Size: torch.Size([283, 768])
# 2022-12-03 03:48:51 - all-mpnet-base-v2-meanpooling - Ds_XbAv7a0s - done: 333 of: 3731 - Start -  Embeddings: 294
# 2022-12-03 03:49:09 - all-mpnet-base-v2-meanpooling - Ds_XbAv7a0s - done: 333 of: 3731 - Emb Size: torch.Size([294, 768])
# 2022-12-03 03:49:09 - all-mpnet-base-v2-meanpooling - zUiyiW5-9tU - done: 334 of: 3731 - Start -  Embeddings: 268
# 2022-12-03 03:49:24 - all-mpnet-base-v2-meanpooling - zUiyiW5-9tU - done: 334 of: 3731 - Emb Size: torch.Size([268, 768])
# 2022-12-03 03:49:24 - all-mpnet-base-v2-meanpooling - 8Sb7j0TSkMo - done: 335 of: 3731 - Start -  Embeddings: 286
# 2022-12-03 03:49:39 - all-mpnet-base-v2-meanpooling - 8Sb7j0TSkMo - done: 335 of: 3731 - Emb Size: torch.Size([286, 768])
# 2022-12-03 03:49:39 - all-mpnet-base-v2-meanpooling - 87aQlNn3I8A - done: 336 of: 3731 - Start -  Embeddings: 106
# 2022-12-03 03:49:46 - all-mpnet-base-v2-meanpooling - 87aQlNn3I8A - done: 336 of: 3731 - Emb Size: torch.Size([106, 768])
# 2022-12-03 03:49:46 - all-mpnet-base-v2-meanpooling - Ji5EXhSA7t8 - done: 337 of: 3731 - Start -  Embeddings: 124
# 2022-12-03 03:49:52 - all-mpnet-base-v2-meanpooling - Ji5EXhSA7t8 - done: 337 of: 3731 - Emb Size: torch.Size([124, 768])
# 2022-12-03 03:49:52 - all-mpnet-base-v2-meanpooling - aQYEmBF5KsI - done: 338 of: 3731 - Start -  Embeddings: 300
# 2022-12-03 03:50:09 - all-mpnet-base-v2-meanpooling - aQYEmBF5KsI - done: 338 of: 3731 - Emb Size: torch.Size([300, 768])
# 2022-12-03 03:50:09 - all-mpnet-base-v2-meanpooling - aQzNSL56fPo - done: 339 of: 3731 - Start -  Embeddings: 270
# 2022-12-03 03:50:23 - all-mpnet-base-v2-meanpooling - aQzNSL56fPo - done: 339 of: 3731 - Emb Size: torch.Size([270, 768])
# 2022-12-03 03:50:23 - all-mpnet-base-v2-meanpooling - xsCgdNOKsGQ - done: 340 of: 3731 - Start -  Embeddings: 275
# 2022-12-03 03:50:37 - all-mpnet-base-v2-meanpooling - xsCgdNOKsGQ - done: 340 of: 3731 - Emb Size: torch.Size([275, 768])
# 2022-12-03 03:50:37 - all-mpnet-base-v2-meanpooling - ZGKaUoqnY0U - done: 341 of: 3731 - Start -  Embeddings: 284
# 2022-12-03 03:50:53 - all-mpnet-base-v2-meanpooling - ZGKaUoqnY0U - done: 341 of: 3731 - Emb Size: torch.Size([284, 768])
# 2022-12-03 03:50:53 - all-mpnet-base-v2-meanpooling - 2H0Fpg9-G74 - done: 342 of: 3731 - Start -  Embeddings: 126
# 2022-12-03 03:51:00 - all-mpnet-base-v2-meanpooling - 2H0Fpg9-G74 - done: 342 of: 3731 - Emb Size: torch.Size([126, 768])
# 2022-12-03 03:51:00 - all-mpnet-base-v2-meanpooling - 12xnsV89mHY - done: 343 of: 3731 - Start -  Embeddings: 103
# 2022-12-03 03:51:06 - all-mpnet-base-v2-meanpooling - 12xnsV89mHY - done: 343 of: 3731 - Emb Size: torch.Size([103, 768])
# 2022-12-03 03:51:06 - all-mpnet-base-v2-meanpooling - hk1Da_y5RFI - done: 344 of: 3731 - Start -  Embeddings: 303
# 2022-12-03 03:51:22 - all-mpnet-base-v2-meanpooling - hk1Da_y5RFI - done: 344 of: 3731 - Emb Size: torch.Size([303, 768])
# 2022-12-03 03:51:22 - all-mpnet-base-v2-meanpooling - QVQ7kfcNBkg - done: 345 of: 3731 - Start -  Embeddings: 270
# 2022-12-03 03:51:36 - all-mpnet-base-v2-meanpooling - QVQ7kfcNBkg - done: 345 of: 3731 - Emb Size: torch.Size([270, 768])
# 2022-12-03 03:51:36 - all-mpnet-base-v2-meanpooling - s8t8aWZ0lNU - done: 346 of: 3731 - Start -  Embeddings: 268
# 2022-12-03 03:51:50 - all-mpnet-base-v2-meanpooling - s8t8aWZ0lNU - done: 346 of: 3731 - Emb Size: torch.Size([268, 768])
# 2022-12-03 03:51:50 - all-mpnet-base-v2-meanpooling - 4q08L1HaZFI - done: 347 of: 3731 - Start -  Embeddings: 275
# 2022-12-03 03:52:06 - all-mpnet-base-v2-meanpooling - 4q08L1HaZFI - done: 347 of: 3731 - Emb Size: torch.Size([275, 768])
# 2022-12-03 03:52:06 - all-mpnet-base-v2-meanpooling - POZuPD4mt-c - done: 348 of: 3731 - Start -  Embeddings: 285
# 2022-12-03 03:52:21 - all-mpnet-base-v2-meanpooling - POZuPD4mt-c - done: 348 of: 3731 - Emb Size: torch.Size([285, 768])
# 2022-12-03 03:52:21 - all-mpnet-base-v2-meanpooling - yVJ0-Cx82H8 - done: 349 of: 3731 - Start -  Embeddings: 125
# 2022-12-03 03:52:27 - all-mpnet-base-v2-meanpooling - yVJ0-Cx82H8 - done: 349 of: 3731 - Emb Size: torch.Size([125, 768])
# 2022-12-03 03:52:27 - all-mpnet-base-v2-meanpooling - 7qVGgcRf9bc - done: 350 of: 3731 - Start -  Embeddings: 97
# 2022-12-03 03:52:34 - all-mpnet-base-v2-meanpooling - 7qVGgcRf9bc - done: 350 of: 3731 - Emb Size: torch.Size([97, 768])
# 2022-12-03 03:52:34 - all-mpnet-base-v2-meanpooling - 5DNOlQZB3wk - done: 351 of: 3731 - Start -  Embeddings: 283
# 2022-12-03 03:52:49 - all-mpnet-base-v2-meanpooling - 5DNOlQZB3wk - done: 351 of: 3731 - Emb Size: torch.Size([283, 768])
# 2022-12-03 03:52:49 - all-mpnet-base-v2-meanpooling - NMUEC3x0N6Q - done: 352 of: 3731 - Start -  Embeddings: 285
# 2022-12-03 03:53:04 - all-mpnet-base-v2-meanpooling - NMUEC3x0N6Q - done: 352 of: 3731 - Emb Size: torch.Size([285, 768])
# 2022-12-03 03:53:04 - all-mpnet-base-v2-meanpooling - E6x76vrNl-E - done: 353 of: 3731 - Start -  Embeddings: 260
# 2022-12-03 03:53:18 - all-mpnet-base-v2-meanpooling - E6x76vrNl-E - done: 353 of: 3731 - Emb Size: torch.Size([260, 768])
# 2022-12-03 03:53:18 - all-mpnet-base-v2-meanpooling - GVYoASDRAkQ - done: 354 of: 3731 - Start -  Embeddings: 286
# 2022-12-03 03:53:35 - all-mpnet-base-v2-meanpooling - GVYoASDRAkQ - done: 354 of: 3731 - Emb Size: torch.Size([286, 768])
# 2022-12-03 03:53:35 - all-mpnet-base-v2-meanpooling - 32hWdyuEhto - done: 355 of: 3731 - Start -  Embeddings: 293
# 2022-12-03 03:53:51 - all-mpnet-base-v2-meanpooling - 32hWdyuEhto - done: 355 of: 3731 - Emb Size: torch.Size([293, 768])
# 2022-12-03 03:53:51 - all-mpnet-base-v2-meanpooling - rA4L2Atf9rc - done: 356 of: 3731 - Start -  Embeddings: 126
# 2022-12-03 03:53:58 - all-mpnet-base-v2-meanpooling - rA4L2Atf9rc - done: 356 of: 3731 - Emb Size: torch.Size([126, 768])
# 2022-12-03 03:53:58 - all-mpnet-base-v2-meanpooling - WmVfMalsLS8 - done: 357 of: 3731 - Start -  Embeddings: 261
# 2022-12-03 03:54:12 - all-mpnet-base-v2-meanpooling - WmVfMalsLS8 - done: 357 of: 3731 - Emb Size: torch.Size([261, 768])
# 2022-12-03 03:54:12 - all-mpnet-base-v2-meanpooling - 6ToA0C3KyIU - done: 358 of: 3731 - Start -  Embeddings: 269
# 2022-12-03 03:54:26 - all-mpnet-base-v2-meanpooling - 6ToA0C3KyIU - done: 358 of: 3731 - Emb Size: torch.Size([269, 768])
# 2022-12-03 03:54:26 - all-mpnet-base-v2-meanpooling - x_oKYVMiEJw - done: 359 of: 3731 - Start -  Embeddings: 264
# 2022-12-03 03:54:39 - all-mpnet-base-v2-meanpooling - x_oKYVMiEJw - done: 359 of: 3731 - Emb Size: torch.Size([264, 768])
# 2022-12-03 03:54:39 - all-mpnet-base-v2-meanpooling - yDzJ1A0cyhg - done: 360 of: 3731 - Start -  Embeddings: 276
# 2022-12-03 03:54:53 - all-mpnet-base-v2-meanpooling - yDzJ1A0cyhg - done: 360 of: 3731 - Emb Size: torch.Size([276, 768])
# 2022-12-03 03:54:53 - all-mpnet-base-v2-meanpooling - hZfLH_O5h0Q - done: 361 of: 3731 - Start -  Embeddings: 269
# 2022-12-03 03:55:08 - all-mpnet-base-v2-meanpooling - hZfLH_O5h0Q - done: 361 of: 3731 - Emb Size: torch.Size([269, 768])
# 2022-12-03 03:55:08 - all-mpnet-base-v2-meanpooling - b3eKXAH7eXQ - done: 362 of: 3731 - Start -  Embeddings: 87
# 2022-12-03 03:55:13 - all-mpnet-base-v2-meanpooling - b3eKXAH7eXQ - done: 362 of: 3731 - Emb Size: torch.Size([87, 768])
# 2022-12-03 03:55:13 - all-mpnet-base-v2-meanpooling - jr19LWi9QCo - done: 363 of: 3731 - Start -  Embeddings: 95
# 2022-12-03 03:55:19 - all-mpnet-base-v2-meanpooling - jr19LWi9QCo - done: 363 of: 3731 - Emb Size: torch.Size([95, 768])
# 2022-12-03 03:55:19 - all-mpnet-base-v2-meanpooling - zi22Vm0Inpg - done: 364 of: 3731 - Start -  Embeddings: 279
# 2022-12-03 03:55:33 - all-mpnet-base-v2-meanpooling - zi22Vm0Inpg - done: 364 of: 3731 - Emb Size: torch.Size([279, 768])
# 2022-12-03 03:55:33 - all-mpnet-base-v2-meanpooling - ed8S1OLrBWI - done: 365 of: 3731 - Start -  Embeddings: 260
# 2022-12-03 03:55:47 - all-mpnet-base-v2-meanpooling - ed8S1OLrBWI - done: 365 of: 3731 - Emb Size: torch.Size([260, 768])
# 2022-12-03 03:55:47 - all-mpnet-base-v2-meanpooling - Yu1WU6Lky4g - done: 366 of: 3731 - Start -  Embeddings: 284
# 2022-12-03 03:56:01 - all-mpnet-base-v2-meanpooling - Yu1WU6Lky4g - done: 366 of: 3731 - Emb Size: torch.Size([284, 768])
# 2022-12-03 03:56:01 - all-mpnet-base-v2-meanpooling - qZATMcwyZCk - done: 367 of: 3731 - Start -  Embeddings: 278
# 2022-12-03 03:56:18 - all-mpnet-base-v2-meanpooling - qZATMcwyZCk - done: 367 of: 3731 - Emb Size: torch.Size([278, 768])
# 2022-12-03 03:56:18 - all-mpnet-base-v2-meanpooling - mDKOfhbmZ70 - done: 368 of: 3731 - Start -  Embeddings: 123
# 2022-12-03 03:56:24 - all-mpnet-base-v2-meanpooling - mDKOfhbmZ70 - done: 368 of: 3731 - Emb Size: torch.Size([123, 768])
# 2022-12-03 03:56:24 - all-mpnet-base-v2-meanpooling - hD4eHjwjerM - done: 369 of: 3731 - Start -  Embeddings: 231
# 2022-12-03 03:56:37 - all-mpnet-base-v2-meanpooling - hD4eHjwjerM - done: 369 of: 3731 - Emb Size: torch.Size([231, 768])
# 2022-12-03 03:56:37 - all-mpnet-base-v2-meanpooling - 6cuU3ST4r8Y - done: 370 of: 3731 - Start -  Embeddings: 272
# 2022-12-03 03:56:51 - all-mpnet-base-v2-meanpooling - 6cuU3ST4r8Y - done: 370 of: 3731 - Emb Size: torch.Size([272, 768])
# 2022-12-03 03:56:51 - all-mpnet-base-v2-meanpooling - uVdAJtrb-7c - done: 371 of: 3731 - Start -  Embeddings: 264
# 2022-12-03 03:57:05 - all-mpnet-base-v2-meanpooling - uVdAJtrb-7c - done: 371 of: 3731 - Emb Size: torch.Size([264, 768])
# 2022-12-03 03:57:05 - all-mpnet-base-v2-meanpooling - 36zGvwtzweQ - done: 372 of: 3731 - Start -  Embeddings: 292
# 2022-12-03 03:57:21 - all-mpnet-base-v2-meanpooling - 36zGvwtzweQ - done: 372 of: 3731 - Emb Size: torch.Size([292, 768])
# 2022-12-03 03:57:21 - all-mpnet-base-v2-meanpooling - eXRgJH9usYg - done: 373 of: 3731 - Start -  Embeddings: 99
# 2022-12-03 03:57:26 - all-mpnet-base-v2-meanpooling - eXRgJH9usYg - done: 373 of: 3731 - Emb Size: torch.Size([99, 768])
# 2022-12-03 03:57:26 - all-mpnet-base-v2-meanpooling - 06sxhqC2KEE - done: 374 of: 3731 - Start -  Embeddings: 264
# 2022-12-03 03:57:40 - all-mpnet-base-v2-meanpooling - 06sxhqC2KEE - done: 374 of: 3731 - Emb Size: torch.Size([264, 768])
# 2022-12-03 03:57:40 - all-mpnet-base-v2-meanpooling - BOTzW0_ywJ4 - done: 375 of: 3731 - Start -  Embeddings: 274
# 2022-12-03 03:57:54 - all-mpnet-base-v2-meanpooling - BOTzW0_ywJ4 - done: 375 of: 3731 - Emb Size: torch.Size([274, 768])
# 2022-12-03 03:57:54 - all-mpnet-base-v2-meanpooling - zEn6RfOYxHU - done: 376 of: 3731 - Start -  Embeddings: 288
# 2022-12-03 03:58:09 - all-mpnet-base-v2-meanpooling - zEn6RfOYxHU - done: 376 of: 3731 - Emb Size: torch.Size([288, 768])
# 2022-12-03 03:58:09 - all-mpnet-base-v2-meanpooling - UXri0kJGDMw - done: 377 of: 3731 - Start -  Embeddings: 87
# 2022-12-03 03:58:13 - all-mpnet-base-v2-meanpooling - UXri0kJGDMw - done: 377 of: 3731 - Emb Size: torch.Size([87, 768])
# 2022-12-03 03:58:13 - all-mpnet-base-v2-meanpooling - Gp38JtF9E6o - done: 378 of: 3731 - Start -  Embeddings: 103
# 2022-12-03 03:58:18 - all-mpnet-base-v2-meanpooling - Gp38JtF9E6o - done: 378 of: 3731 - Emb Size: torch.Size([103, 768])
# 2022-12-03 03:58:18 - all-mpnet-base-v2-meanpooling - Wxt64Wi1fKs - done: 379 of: 3731 - Start -  Embeddings: 294
# 2022-12-03 03:58:34 - all-mpnet-base-v2-meanpooling - Wxt64Wi1fKs - done: 379 of: 3731 - Emb Size: torch.Size([294, 768])
# 2022-12-03 03:58:34 - all-mpnet-base-v2-meanpooling - HvRgRPk8O_A - done: 380 of: 3731 - Start -  Embeddings: 275
# 2022-12-03 03:58:49 - all-mpnet-base-v2-meanpooling - HvRgRPk8O_A - done: 380 of: 3731 - Emb Size: torch.Size([275, 768])
# 2022-12-03 03:58:49 - all-mpnet-base-v2-meanpooling - yx4J6AI54dY - done: 381 of: 3731 - Start -  Embeddings: 277
# 2022-12-03 03:59:04 - all-mpnet-base-v2-meanpooling - yx4J6AI54dY - done: 381 of: 3731 - Emb Size: torch.Size([277, 768])
# 2022-12-03 03:59:04 - all-mpnet-base-v2-meanpooling - JNHvJnTkSxU - done: 382 of: 3731 - Start -  Embeddings: 280
# 2022-12-03 03:59:19 - all-mpnet-base-v2-meanpooling - JNHvJnTkSxU - done: 382 of: 3731 - Emb Size: torch.Size([280, 768])
# 2022-12-03 03:59:19 - all-mpnet-base-v2-meanpooling - tKTCKbKANlM - done: 383 of: 3731 - Start -  Embeddings: 289
# 2022-12-03 03:59:35 - all-mpnet-base-v2-meanpooling - tKTCKbKANlM - done: 383 of: 3731 - Emb Size: torch.Size([289, 768])
# 2022-12-03 03:59:35 - all-mpnet-base-v2-meanpooling - o0UiBGNrzzA - done: 384 of: 3731 - Start -  Embeddings: 112
# 2022-12-03 03:59:40 - all-mpnet-base-v2-meanpooling - o0UiBGNrzzA - done: 384 of: 3731 - Emb Size: torch.Size([112, 768])
# 2022-12-03 03:59:40 - all-mpnet-base-v2-meanpooling - NWsLmMEEDCI - done: 385 of: 3731 - Start -  Embeddings: 86
# 2022-12-03 03:59:46 - all-mpnet-base-v2-meanpooling - NWsLmMEEDCI - done: 385 of: 3731 - Emb Size: torch.Size([86, 768])
# 2022-12-03 03:59:46 - all-mpnet-base-v2-meanpooling - XWIuAZ84NgE - done: 386 of: 3731 - Start -  Embeddings: 277
# 2022-12-03 04:00:03 - all-mpnet-base-v2-meanpooling - XWIuAZ84NgE - done: 386 of: 3731 - Emb Size: torch.Size([277, 768])
# 2022-12-03 04:00:03 - all-mpnet-base-v2-meanpooling - iPnKnMNJJDE - done: 387 of: 3731 - Start -  Embeddings: 285
# 2022-12-03 04:00:18 - all-mpnet-base-v2-meanpooling - iPnKnMNJJDE - done: 387 of: 3731 - Emb Size: torch.Size([285, 768])
# 2022-12-03 04:00:18 - all-mpnet-base-v2-meanpooling - 7AAepDvBlqM - done: 388 of: 3731 - Start -  Embeddings: 289
# 2022-12-03 04:00:33 - all-mpnet-base-v2-meanpooling - 7AAepDvBlqM - done: 388 of: 3731 - Emb Size: torch.Size([289, 768])
# 2022-12-03 04:00:33 - all-mpnet-base-v2-meanpooling - IiWLERZtNYQ - done: 389 of: 3731 - Start -  Embeddings: 265
# 2022-12-03 04:00:48 - all-mpnet-base-v2-meanpooling - IiWLERZtNYQ - done: 389 of: 3731 - Emb Size: torch.Size([265, 768])
# 2022-12-03 04:00:48 - all-mpnet-base-v2-meanpooling - s59VgReG7Y8 - done: 390 of: 3731 - Start -  Embeddings: 96
# 2022-12-03 04:00:53 - all-mpnet-base-v2-meanpooling - s59VgReG7Y8 - done: 390 of: 3731 - Emb Size: torch.Size([96, 768])
# 2022-12-03 04:00:53 - all-mpnet-base-v2-meanpooling - _QncAyFfDXk - done: 391 of: 3731 - Start -  Embeddings: 99
# 2022-12-03 04:00:59 - all-mpnet-base-v2-meanpooling - _QncAyFfDXk - done: 391 of: 3731 - Emb Size: torch.Size([99, 768])
# 2022-12-03 04:00:59 - all-mpnet-base-v2-meanpooling - mOMkJ9IiJnc - done: 392 of: 3731 - Start -  Embeddings: 292
# 2022-12-03 04:01:15 - all-mpnet-base-v2-meanpooling - mOMkJ9IiJnc - done: 392 of: 3731 - Emb Size: torch.Size([292, 768])
# 2022-12-03 04:01:15 - all-mpnet-base-v2-meanpooling - Qm0lhFNjK8w - done: 393 of: 3731 - Start -  Embeddings: 293
# 2022-12-03 04:01:30 - all-mpnet-base-v2-meanpooling - Qm0lhFNjK8w - done: 393 of: 3731 - Emb Size: torch.Size([293, 768])
# 2022-12-03 04:01:30 - all-mpnet-base-v2-meanpooling - ar1tL9bWe3w - done: 394 of: 3731 - Start -  Embeddings: 282
# 2022-12-03 04:01:45 - all-mpnet-base-v2-meanpooling - ar1tL9bWe3w - done: 394 of: 3731 - Emb Size: torch.Size([282, 768])
# 2022-12-03 04:01:45 - all-mpnet-base-v2-meanpooling - 41sIT9M3kWQ - done: 395 of: 3731 - Start -  Embeddings: 97
# 2022-12-03 04:01:50 - all-mpnet-base-v2-meanpooling - 41sIT9M3kWQ - done: 395 of: 3731 - Emb Size: torch.Size([97, 768])
# 2022-12-03 04:01:50 - all-mpnet-base-v2-meanpooling - IT8HTbXjpZ8 - done: 396 of: 3731 - Start -  Embeddings: 284
# 2022-12-03 04:02:06 - all-mpnet-base-v2-meanpooling - IT8HTbXjpZ8 - done: 396 of: 3731 - Emb Size: torch.Size([284, 768])
# 2022-12-03 04:02:06 - all-mpnet-base-v2-meanpooling - GovwPxi41rA - done: 397 of: 3731 - Start -  Embeddings: 290
# 2022-12-03 04:02:21 - all-mpnet-base-v2-meanpooling - GovwPxi41rA - done: 397 of: 3731 - Emb Size: torch.Size([290, 768])
# 2022-12-03 04:02:21 - all-mpnet-base-v2-meanpooling - 7xkYXdA6dAE - done: 398 of: 3731 - Start -  Embeddings: 288
# 2022-12-03 04:02:37 - all-mpnet-base-v2-meanpooling - 7xkYXdA6dAE - done: 398 of: 3731 - Emb Size: torch.Size([288, 768])
# 2022-12-03 04:02:37 - all-mpnet-base-v2-meanpooling - yNQXKMvUZRg - done: 399 of: 3731 - Start -  Embeddings: 246
# 2022-12-03 04:02:51 - all-mpnet-base-v2-meanpooling - yNQXKMvUZRg - done: 399 of: 3731 - Emb Size: torch.Size([246, 768])
# 2022-12-03 04:02:51 - all-mpnet-base-v2-meanpooling - 2ewo2iTGxJg - done: 400 of: 3731 - Start -  Embeddings: 122
# 2022-12-03 04:02:57 - all-mpnet-base-v2-meanpooling - 2ewo2iTGxJg - done: 400 of: 3731 - Emb Size: torch.Size([122, 768])
# 2022-12-03 04:02:57 - all-mpnet-base-v2-meanpooling - E1bS5EXclxk - done: 401 of: 3731 - Start -  Embeddings: 92
# 2022-12-03 04:03:02 - all-mpnet-base-v2-meanpooling - E1bS5EXclxk - done: 401 of: 3731 - Emb Size: torch.Size([92, 768])
# 2022-12-03 04:03:02 - all-mpnet-base-v2-meanpooling - vUrSTlU8EJ4 - done: 402 of: 3731 - Start -  Embeddings: 283
# 2022-12-03 04:03:20 - all-mpnet-base-v2-meanpooling - vUrSTlU8EJ4 - done: 402 of: 3731 - Emb Size: torch.Size([283, 768])
# 2022-12-03 04:03:20 - all-mpnet-base-v2-meanpooling - Zp5m8U3w0BU - done: 403 of: 3731 - Start -  Embeddings: 273
# 2022-12-03 04:03:35 - all-mpnet-base-v2-meanpooling - Zp5m8U3w0BU - done: 403 of: 3731 - Emb Size: torch.Size([273, 768])
# 2022-12-03 04:03:35 - all-mpnet-base-v2-meanpooling - NwLPkPghWBk - done: 404 of: 3731 - Start -  Embeddings: 268
# 2022-12-03 04:03:52 - all-mpnet-base-v2-meanpooling - NwLPkPghWBk - done: 404 of: 3731 - Emb Size: torch.Size([268, 768])
# 2022-12-03 04:03:52 - all-mpnet-base-v2-meanpooling - aoKrWSIYRfc - done: 405 of: 3731 - Start -  Embeddings: 273
# 2022-12-03 04:04:07 - all-mpnet-base-v2-meanpooling - aoKrWSIYRfc - done: 405 of: 3731 - Emb Size: torch.Size([273, 768])
# 2022-12-03 04:04:07 - all-mpnet-base-v2-meanpooling - wLM4QWC3Xe0 - done: 406 of: 3731 - Start -  Embeddings: 95
# 2022-12-03 04:04:12 - all-mpnet-base-v2-meanpooling - wLM4QWC3Xe0 - done: 406 of: 3731 - Emb Size: torch.Size([95, 768])
# 2022-12-03 04:04:12 - all-mpnet-base-v2-meanpooling - bAfEvAFxKOU - done: 407 of: 3731 - Start -  Embeddings: 268
# 2022-12-03 04:04:26 - all-mpnet-base-v2-meanpooling - bAfEvAFxKOU - done: 407 of: 3731 - Emb Size: torch.Size([268, 768])
# 2022-12-03 04:04:26 - all-mpnet-base-v2-meanpooling - bhM2rT38JXE - done: 408 of: 3731 - Start -  Embeddings: 290
# 2022-12-03 04:04:42 - all-mpnet-base-v2-meanpooling - bhM2rT38JXE - done: 408 of: 3731 - Emb Size: torch.Size([290, 768])
# 2022-12-03 04:04:42 - all-mpnet-base-v2-meanpooling - WYiYz41GXNo - done: 409 of: 3731 - Start -  Embeddings: 279
# 2022-12-03 04:04:57 - all-mpnet-base-v2-meanpooling - WYiYz41GXNo - done: 409 of: 3731 - Emb Size: torch.Size([279, 768])
# 2022-12-03 04:04:57 - all-mpnet-base-v2-meanpooling - hfAzVL4mCeY - done: 410 of: 3731 - Start -  Embeddings: 302
# 2022-12-03 04:05:13 - all-mpnet-base-v2-meanpooling - hfAzVL4mCeY - done: 410 of: 3731 - Emb Size: torch.Size([302, 768])
# 2022-12-03 04:05:13 - all-mpnet-base-v2-meanpooling - izXMXguBIe4 - done: 411 of: 3731 - Start -  Embeddings: 95
# 2022-12-03 04:05:18 - all-mpnet-base-v2-meanpooling - izXMXguBIe4 - done: 411 of: 3731 - Emb Size: torch.Size([95, 768])
# 2022-12-03 04:05:18 - all-mpnet-base-v2-meanpooling - kwDExL6L5tU - done: 412 of: 3731 - Start -  Embeddings: 91
# 2022-12-03 04:05:23 - all-mpnet-base-v2-meanpooling - kwDExL6L5tU - done: 412 of: 3731 - Emb Size: torch.Size([91, 768])
# 2022-12-03 04:05:23 - all-mpnet-base-v2-meanpooling - lObpBWhp5KI - done: 413 of: 3731 - Start -  Embeddings: 303
# 2022-12-03 04:05:40 - all-mpnet-base-v2-meanpooling - lObpBWhp5KI - done: 413 of: 3731 - Emb Size: torch.Size([303, 768])
# 2022-12-03 04:05:40 - all-mpnet-base-v2-meanpooling - vmbsD5kfvEM - done: 414 of: 3731 - Start -  Embeddings: 278
# 2022-12-03 04:05:55 - all-mpnet-base-v2-meanpooling - vmbsD5kfvEM - done: 414 of: 3731 - Emb Size: torch.Size([278, 768])
# 2022-12-03 04:05:55 - all-mpnet-base-v2-meanpooling - QZu0NBvNhdI - done: 415 of: 3731 - Start -  Embeddings: 276
# 2022-12-03 04:06:10 - all-mpnet-base-v2-meanpooling - QZu0NBvNhdI - done: 415 of: 3731 - Emb Size: torch.Size([276, 768])
# 2022-12-03 04:06:10 - all-mpnet-base-v2-meanpooling - YFOG4hSN44c - done: 416 of: 3731 - Start -  Embeddings: 280
# 2022-12-03 04:06:25 - all-mpnet-base-v2-meanpooling - YFOG4hSN44c - done: 416 of: 3731 - Emb Size: torch.Size([280, 768])
# 2022-12-03 04:06:25 - all-mpnet-base-v2-meanpooling - cBs65XBXhzU - done: 417 of: 3731 - Start -  Embeddings: 275
# 2022-12-03 04:06:39 - all-mpnet-base-v2-meanpooling - cBs65XBXhzU - done: 417 of: 3731 - Emb Size: torch.Size([275, 768])
# 2022-12-03 04:06:39 - all-mpnet-base-v2-meanpooling - RdKaP-bCsFQ - done: 418 of: 3731 - Start -  Embeddings: 128
# 2022-12-03 04:06:46 - all-mpnet-base-v2-meanpooling - RdKaP-bCsFQ - done: 418 of: 3731 - Emb Size: torch.Size([128, 768])
# 2022-12-03 04:06:46 - all-mpnet-base-v2-meanpooling - 1gNGpJCLEBs - done: 419 of: 3731 - Start -  Embeddings: 120
# 2022-12-03 04:06:55 - all-mpnet-base-v2-meanpooling - 1gNGpJCLEBs - done: 419 of: 3731 - Emb Size: torch.Size([120, 768])
# 2022-12-03 04:06:55 - all-mpnet-base-v2-meanpooling - jt_NVQ7L8AY - done: 420 of: 3731 - Start -  Embeddings: 306
# 2022-12-03 04:07:10 - all-mpnet-base-v2-meanpooling - jt_NVQ7L8AY - done: 420 of: 3731 - Emb Size: torch.Size([306, 768])
# 2022-12-03 04:07:10 - all-mpnet-base-v2-meanpooling - tRgu2mR9ROY - done: 421 of: 3731 - Start -  Embeddings: 436
# 2022-12-03 04:07:27 - all-mpnet-base-v2-meanpooling - tRgu2mR9ROY - done: 421 of: 3731 - Emb Size: torch.Size([436, 768])
# 2022-12-03 04:07:27 - all-mpnet-base-v2-meanpooling - vswKpyLZRbc - done: 422 of: 3731 - Start -  Embeddings: 271
# 2022-12-03 04:07:41 - all-mpnet-base-v2-meanpooling - vswKpyLZRbc - done: 422 of: 3731 - Emb Size: torch.Size([271, 768])
# 2022-12-03 04:07:41 - all-mpnet-base-v2-meanpooling - lwGfUy9Pm5s - done: 423 of: 3731 - Start -  Embeddings: 281
# 2022-12-03 04:07:56 - all-mpnet-base-v2-meanpooling - lwGfUy9Pm5s - done: 423 of: 3731 - Emb Size: torch.Size([281, 768])
# 2022-12-03 04:07:56 - all-mpnet-base-v2-meanpooling - _XXFloQkfWI - done: 424 of: 3731 - Start -  Embeddings: 291
# 2022-12-03 04:08:11 - all-mpnet-base-v2-meanpooling - _XXFloQkfWI - done: 424 of: 3731 - Emb Size: torch.Size([291, 768])
# 2022-12-03 04:08:11 - all-mpnet-base-v2-meanpooling - 7ui0Z6VjSaM - done: 425 of: 3731 - Start -  Embeddings: 99
# 2022-12-03 04:08:16 - all-mpnet-base-v2-meanpooling - 7ui0Z6VjSaM - done: 425 of: 3731 - Emb Size: torch.Size([99, 768])
# 2022-12-03 04:08:16 - all-mpnet-base-v2-meanpooling - MU4LTaBbFCs - done: 426 of: 3731 - Start -  Embeddings: 142
# 2022-12-03 04:08:24 - all-mpnet-base-v2-meanpooling - MU4LTaBbFCs - done: 426 of: 3731 - Emb Size: torch.Size([142, 768])
# 2022-12-03 04:08:24 - all-mpnet-base-v2-meanpooling - h_bRfzsvWXQ - done: 427 of: 3731 - Start -  Embeddings: 260
# 2022-12-03 04:08:37 - all-mpnet-base-v2-meanpooling - h_bRfzsvWXQ - done: 427 of: 3731 - Emb Size: torch.Size([260, 768])
# 2022-12-03 04:08:37 - all-mpnet-base-v2-meanpooling - BhWTgGru6J0 - done: 428 of: 3731 - Start -  Embeddings: 272
# 2022-12-03 04:08:51 - all-mpnet-base-v2-meanpooling - BhWTgGru6J0 - done: 428 of: 3731 - Emb Size: torch.Size([272, 768])
# 2022-12-03 04:08:51 - all-mpnet-base-v2-meanpooling - yzpCAV2eOuk - done: 429 of: 3731 - Start -  Embeddings: 100
# 2022-12-03 04:08:57 - all-mpnet-base-v2-meanpooling - yzpCAV2eOuk - done: 429 of: 3731 - Emb Size: torch.Size([100, 768])
# 2022-12-03 04:08:57 - all-mpnet-base-v2-meanpooling - BOpubM3yG4o - done: 430 of: 3731 - Start -  Embeddings: 96
# 2022-12-03 04:09:03 - all-mpnet-base-v2-meanpooling - BOpubM3yG4o - done: 430 of: 3731 - Emb Size: torch.Size([96, 768])
# 2022-12-03 04:09:03 - all-mpnet-base-v2-meanpooling - Sk8TQeqqz0U - done: 431 of: 3731 - Start -  Embeddings: 275
# 2022-12-03 04:09:18 - all-mpnet-base-v2-meanpooling - Sk8TQeqqz0U - done: 431 of: 3731 - Emb Size: torch.Size([275, 768])
# 2022-12-03 04:09:18 - all-mpnet-base-v2-meanpooling - muvDyp-jDDI - done: 432 of: 3731 - Start -  Embeddings: 267
# 2022-12-03 04:09:35 - all-mpnet-base-v2-meanpooling - muvDyp-jDDI - done: 432 of: 3731 - Emb Size: torch.Size([267, 768])
# 2022-12-03 04:09:35 - all-mpnet-base-v2-meanpooling - CiwOM-0PBQY - done: 433 of: 3731 - Start -  Embeddings: 298
# 2022-12-03 04:09:50 - all-mpnet-base-v2-meanpooling - CiwOM-0PBQY - done: 433 of: 3731 - Emb Size: torch.Size([298, 768])
# 2022-12-03 04:09:50 - all-mpnet-base-v2-meanpooling - 392rMVFFME4 - done: 434 of: 3731 - Start -  Embeddings: 279
# 2022-12-03 04:10:04 - all-mpnet-base-v2-meanpooling - 392rMVFFME4 - done: 434 of: 3731 - Emb Size: torch.Size([279, 768])
# 2022-12-03 04:10:04 - all-mpnet-base-v2-meanpooling - D5X0tAecfF4 - done: 435 of: 3731 - Start -  Embeddings: 825
# 2022-12-03 04:10:29 - all-mpnet-base-v2-meanpooling - D5X0tAecfF4 - done: 435 of: 3731 - Emb Size: torch.Size([825, 768])
# 2022-12-03 04:10:29 - all-mpnet-base-v2-meanpooling - Z6RTYZz4EtQ - done: 436 of: 3731 - Start -  Embeddings: 1006
# 2022-12-03 04:10:58 - all-mpnet-base-v2-meanpooling - Z6RTYZz4EtQ - done: 436 of: 3731 - Emb Size: torch.Size([1006, 768])
# 2022-12-03 04:10:58 - all-mpnet-base-v2-meanpooling - 8CJt2VwDuLE - done: 437 of: 3731 - Start -  Embeddings: 662
# 2022-12-03 04:11:16 - all-mpnet-base-v2-meanpooling - 8CJt2VwDuLE - done: 437 of: 3731 - Emb Size: torch.Size([662, 768])
# 2022-12-03 04:11:16 - all-mpnet-base-v2-meanpooling - RzKM-VwriK0 - done: 438 of: 3731 - Start -  Embeddings: 940
# 2022-12-03 04:11:43 - all-mpnet-base-v2-meanpooling - RzKM-VwriK0 - done: 438 of: 3731 - Emb Size: torch.Size([940, 768])
# 2022-12-03 04:11:43 - all-mpnet-base-v2-meanpooling - v3yxlAGV_WI - done: 439 of: 3731 - Start -  Embeddings: 777
# 2022-12-03 04:12:04 - all-mpnet-base-v2-meanpooling - v3yxlAGV_WI - done: 439 of: 3731 - Emb Size: torch.Size([777, 768])
# 2022-12-03 04:12:04 - all-mpnet-base-v2-meanpooling - tJE8HYFrkT4 - done: 440 of: 3731 - Start -  Embeddings: 661
# 2022-12-03 04:12:24 - all-mpnet-base-v2-meanpooling - tJE8HYFrkT4 - done: 440 of: 3731 - Emb Size: torch.Size([661, 768])
# 2022-12-03 04:12:24 - all-mpnet-base-v2-meanpooling - feS1zuKz2N8 - done: 441 of: 3731 - Start -  Embeddings: 803
# 2022-12-03 04:12:48 - all-mpnet-base-v2-meanpooling - feS1zuKz2N8 - done: 441 of: 3731 - Emb Size: torch.Size([803, 768])
# 2022-12-03 04:12:48 - all-mpnet-base-v2-meanpooling - gqS1ov4lSI0 - done: 442 of: 3731 - Start -  Embeddings: 872
# 2022-12-03 04:13:14 - all-mpnet-base-v2-meanpooling - gqS1ov4lSI0 - done: 442 of: 3731 - Emb Size: torch.Size([872, 768])
# 2022-12-03 04:13:14 - all-mpnet-base-v2-meanpooling - z-mJEZbHFLs - done: 443 of: 3731 - Start -  Embeddings: 969
# 2022-12-03 04:13:42 - all-mpnet-base-v2-meanpooling - z-mJEZbHFLs - done: 443 of: 3731 - Emb Size: torch.Size([969, 768])
# 2022-12-03 04:13:42 - all-mpnet-base-v2-meanpooling - -aFcTbf8yI8 - done: 444 of: 3731 - Start -  Embeddings: 955
# 2022-12-03 04:14:08 - all-mpnet-base-v2-meanpooling - -aFcTbf8yI8 - done: 444 of: 3731 - Emb Size: torch.Size([955, 768])
# 2022-12-03 04:14:08 - all-mpnet-base-v2-meanpooling - ZAaY0gbis4s - done: 445 of: 3731 - Start -  Embeddings: 837
# 2022-12-03 04:14:32 - all-mpnet-base-v2-meanpooling - ZAaY0gbis4s - done: 445 of: 3731 - Emb Size: torch.Size([837, 768])
# 2022-12-03 04:14:32 - all-mpnet-base-v2-meanpooling - GRSwDBMiaWQ - done: 446 of: 3731 - Start -  Embeddings: 863
# 2022-12-03 04:14:58 - all-mpnet-base-v2-meanpooling - GRSwDBMiaWQ - done: 446 of: 3731 - Emb Size: torch.Size([863, 768])
# 2022-12-03 04:14:58 - all-mpnet-base-v2-meanpooling - 8R-vkbxX8r4 - done: 447 of: 3731 - Start -  Embeddings: 1119
# 2022-12-03 04:15:32 - all-mpnet-base-v2-meanpooling - 8R-vkbxX8r4 - done: 447 of: 3731 - Emb Size: torch.Size([1119, 768])
# 2022-12-03 04:15:32 - all-mpnet-base-v2-meanpooling - eKa8X5vjtjc - done: 448 of: 3731 - Start -  Embeddings: 940
# 2022-12-03 04:16:00 - all-mpnet-base-v2-meanpooling - eKa8X5vjtjc - done: 448 of: 3731 - Emb Size: torch.Size([940, 768])
# 2022-12-03 04:16:00 - all-mpnet-base-v2-meanpooling - 4Modzh94MVw - done: 449 of: 3731 - Start -  Embeddings: 805
# 2022-12-03 04:16:23 - all-mpnet-base-v2-meanpooling - 4Modzh94MVw - done: 449 of: 3731 - Emb Size: torch.Size([805, 768])
# 2022-12-03 04:16:23 - all-mpnet-base-v2-meanpooling - 99b_UFNamWA - done: 450 of: 3731 - Start -  Embeddings: 971
# 2022-12-03 04:16:53 - all-mpnet-base-v2-meanpooling - 99b_UFNamWA - done: 450 of: 3731 - Emb Size: torch.Size([971, 768])
# 2022-12-03 04:16:53 - all-mpnet-base-v2-meanpooling - gODDs5Auqfc - done: 451 of: 3731 - Start -  Embeddings: 963
# 2022-12-03 04:17:19 - all-mpnet-base-v2-meanpooling - gODDs5Auqfc - done: 451 of: 3731 - Emb Size: torch.Size([963, 768])
# 2022-12-03 04:17:19 - all-mpnet-base-v2-meanpooling - mDJ65ortiLo - done: 452 of: 3731 - Start -  Embeddings: 723
# 2022-12-03 04:17:39 - all-mpnet-base-v2-meanpooling - mDJ65ortiLo - done: 452 of: 3731 - Emb Size: torch.Size([723, 768])
# 2022-12-03 04:17:39 - all-mpnet-base-v2-meanpooling - aa0cLA0Gm0M - done: 453 of: 3731 - Start -  Embeddings: 1185
# 2022-12-03 04:18:13 - all-mpnet-base-v2-meanpooling - aa0cLA0Gm0M - done: 453 of: 3731 - Emb Size: torch.Size([1185, 768])
# 2022-12-03 04:18:13 - all-mpnet-base-v2-meanpooling - LfefNZDlq6o - done: 454 of: 3731 - Start -  Embeddings: 1058
# 2022-12-03 04:18:43 - all-mpnet-base-v2-meanpooling - LfefNZDlq6o - done: 454 of: 3731 - Emb Size: torch.Size([1058, 768])
# 2022-12-03 04:18:43 - all-mpnet-base-v2-meanpooling - 7h7oqlG_FxE - done: 455 of: 3731 - Start -  Embeddings: 981
# 2022-12-03 04:19:10 - all-mpnet-base-v2-meanpooling - 7h7oqlG_FxE - done: 455 of: 3731 - Emb Size: torch.Size([981, 768])
# 2022-12-03 04:19:10 - all-mpnet-base-v2-meanpooling - o74rQmLRqtA - done: 456 of: 3731 - Start -  Embeddings: 790
# 2022-12-03 04:19:30 - all-mpnet-base-v2-meanpooling - o74rQmLRqtA - done: 456 of: 3731 - Emb Size: torch.Size([790, 768])
# 2022-12-03 04:19:30 - all-mpnet-base-v2-meanpooling - 8BwD6hJeC6w - done: 457 of: 3731 - Start -  Embeddings: 736
# 2022-12-03 04:19:50 - all-mpnet-base-v2-meanpooling - 8BwD6hJeC6w - done: 457 of: 3731 - Emb Size: torch.Size([736, 768])
# 2022-12-03 04:19:50 - all-mpnet-base-v2-meanpooling - ld_5qT1Y6ec - done: 458 of: 3731 - Start -  Embeddings: 468
# 2022-12-03 04:20:06 - all-mpnet-base-v2-meanpooling - ld_5qT1Y6ec - done: 458 of: 3731 - Emb Size: torch.Size([468, 768])
# 2022-12-03 04:20:06 - all-mpnet-base-v2-meanpooling - W7VfhuRHp2c - done: 459 of: 3731 - Start -  Embeddings: 748
# 2022-12-03 04:20:26 - all-mpnet-base-v2-meanpooling - W7VfhuRHp2c - done: 459 of: 3731 - Emb Size: torch.Size([748, 768])
# 2022-12-03 04:20:26 - all-mpnet-base-v2-meanpooling - iPcILp35oU4 - done: 460 of: 3731 - Start -  Embeddings: 1007
# 2022-12-03 04:20:55 - all-mpnet-base-v2-meanpooling - iPcILp35oU4 - done: 460 of: 3731 - Emb Size: torch.Size([1007, 768])
# 2022-12-03 04:20:55 - all-mpnet-base-v2-meanpooling - lAqCISsZEM4 - done: 461 of: 3731 - Start -  Embeddings: 1040
# ...
# 2022-12-03 16:02:46 - all-mpnet-base-v2-meanpooling - nBxRQtfv7dM - done: 2712 of: 3731 - Emb Size: torch.Size([1121, 768])
# 2022-12-03 16:02:46 - all-mpnet-base-v2-meanpooling - i5UaDiarMog - done: 2713 of: 3731 - Start -  Embeddings: 490
# 2022-12-03 16:03:01 - all-mpnet-base-v2-meanpooling - i5UaDiarMog - done: 2713 of: 3731 - Emb Size: torch.Size([490, 768])
# 2022-12-03 16:03:01 - all-mpnet-base-v2-meanpooling - _4jj5M9KtUk - done: 2714 of: 3731 - Start -  Embeddings: 1876
# 2022-12-03 16:03:56 - all-mpnet-base-v2-meanpooling - _4jj5M9KtUk - done: 2714 of: 3731 - Emb Size: torch.Size([1876, 768])
# 2022-12-03 16:03:56 - all-mpnet-base-v2-meanpooling - AEpD2o6MZOk - done: 2715 of: 3731 - Start -  Embeddings: 953
# 2022-12-03 16:04:23 - all-mpnet-base-v2-meanpooling - AEpD2o6MZOk - done: 2715 of: 3731 - Emb Size: torch.Size([953, 768])
# 2022-12-03 16:04:23 - all-mpnet-base-v2-meanpooling - S4sP6hiR7e4 - done: 2716 of: 3731 - Start -  Embeddings: 88
# 2022-12-03 16:04:26 - all-mpnet-base-v2-meanpooling - S4sP6hiR7e4 - done: 2716 of: 3731 - Emb Size: torch.Size([88, 768])
# 2022-12-03 16:04:26 - all-mpnet-base-v2-meanpooling - GmQFpvK1aYY - done: 2717 of: 3731 - Start -  Embeddings: 2225
# 2022-12-03 16:05:42 - all-mpnet-base-v2-meanpooling - GmQFpvK1aYY - done: 2717 of: 3731 - Emb Size: torch.Size([2225, 768])
# 2022-12-03 16:05:42 - all-mpnet-base-v2-meanpooling - hcxzdcV8xaU - done: 2718 of: 3731 - Start -  Embeddings: 1948
# 2022-12-03 16:06:44 - all-mpnet-base-v2-meanpooling - hcxzdcV8xaU - done: 2718 of: 3731 - Emb Size: torch.Size([1948, 768])
# 2022-12-03 16:06:44 - all-mpnet-base-v2-meanpooling - 6LDP_SyswNk - done: 2719 of: 3731 - Start -  Embeddings: 1341
# 2022-12-03 16:07:23 - all-mpnet-base-v2-meanpooling - 6LDP_SyswNk - done: 2719 of: 3731 - Emb Size: torch.Size([1341, 768])
# 2022-12-03 16:07:23 - all-mpnet-base-v2-meanpooling - DOvruQ86STc - done: 2720 of: 3731 - Start -  Embeddings: 941
# 2022-12-03 16:07:53 - all-mpnet-base-v2-meanpooling - DOvruQ86STc - done: 2720 of: 3731 - Emb Size: torch.Size([941, 768])
# 2022-12-03 16:07:53 - all-mpnet-base-v2-meanpooling - xBrNyEEM9dI - done: 2721 of: 3731 - Start -  Embeddings: 649
# 2022-12-03 16:08:13 - all-mpnet-base-v2-meanpooling - xBrNyEEM9dI - done: 2721 of: 3731 - Emb Size: torch.Size([649, 768])
# 2022-12-03 16:08:13 - all-mpnet-base-v2-meanpooling - kvPD0jIvnGI - done: 2722 of: 3731 - Start -  Embeddings: 1795
# 2022-12-03 16:09:16 - all-mpnet-base-v2-meanpooling - kvPD0jIvnGI - done: 2722 of: 3731 - Emb Size: torch.Size([1795, 768])
# 2022-12-03 16:09:16 - all-mpnet-base-v2-meanpooling - dyQUixQZiNo - done: 2723 of: 3731 - Start -  Embeddings: 556
# 2022-12-03 16:09:35 - all-mpnet-base-v2-meanpooling - dyQUixQZiNo - done: 2723 of: 3731 - Emb Size: torch.Size([556, 768])
# 2022-12-03 16:09:35 - all-mpnet-base-v2-meanpooling - W2HskRdN5YI - done: 2724 of: 3731 - Start -  Embeddings: 80
# 2022-12-03 16:09:38 - all-mpnet-base-v2-meanpooling - W2HskRdN5YI - done: 2724 of: 3731 - Emb Size: torch.Size([80, 768])
# 2022-12-03 16:09:38 - all-mpnet-base-v2-meanpooling - 7iREwHWqKz4 - done: 2725 of: 3731 - Start -  Embeddings: 251
# 2022-12-03 16:09:46 - all-mpnet-base-v2-meanpooling - 7iREwHWqKz4 - done: 2725 of: 3731 - Emb Size: torch.Size([251, 768])
# 2022-12-03 16:09:46 - all-mpnet-base-v2-meanpooling - X3KNfDjxzO8 - done: 2726 of: 3731 - Start -  Embeddings: 1114
# 2022-12-03 16:10:24 - all-mpnet-base-v2-meanpooling - X3KNfDjxzO8 - done: 2726 of: 3731 - Emb Size: torch.Size([1114, 768])
# 2022-12-03 16:10:24 - all-mpnet-base-v2-meanpooling - ssPdp7Sj1B4 - done: 2727 of: 3731 - Start -  Embeddings: 591
# 2022-12-03 16:10:44 - all-mpnet-base-v2-meanpooling - ssPdp7Sj1B4 - done: 2727 of: 3731 - Emb Size: torch.Size([591, 768])
# 2022-12-03 16:10:44 - all-mpnet-base-v2-meanpooling - 2wP3GFYYDKA - done: 2728 of: 3731 - Start -  Embeddings: 395
# 2022-12-03 16:10:59 - all-mpnet-base-v2-meanpooling - 2wP3GFYYDKA - done: 2728 of: 3731 - Emb Size: torch.Size([395, 768])
# 2022-12-03 16:10:59 - all-mpnet-base-v2-meanpooling - U5Hn7y1QOjA - done: 2729 of: 3731 - Start -  Embeddings: 88
# 2022-12-03 16:11:01 - all-mpnet-base-v2-meanpooling - U5Hn7y1QOjA - done: 2729 of: 3731 - Emb Size: torch.Size([88, 768])
# 2022-12-03 16:11:02 - all-mpnet-base-v2-meanpooling - H8xxDTebLno - done: 2730 of: 3731 - Start -  Embeddings: 413
# 2022-12-03 16:11:14 - all-mpnet-base-v2-meanpooling - H8xxDTebLno - done: 2730 of: 3731 - Emb Size: torch.Size([413, 768])
# 2022-12-03 16:11:14 - all-mpnet-base-v2-meanpooling - hwyaUlrxWD0 - done: 2731 of: 3731 - Start -  Embeddings: 1062
# 2022-12-03 16:11:54 - all-mpnet-base-v2-meanpooling - hwyaUlrxWD0 - done: 2731 of: 3731 - Emb Size: torch.Size([1062, 768])
# 2022-12-03 16:11:54 - all-mpnet-base-v2-meanpooling - O-ejd-5g32o - done: 2732 of: 3731 - Start -  Embeddings: 72
# 2022-12-03 16:11:56 - all-mpnet-base-v2-meanpooling - O-ejd-5g32o - done: 2732 of: 3731 - Emb Size: torch.Size([72, 768])
# 2022-12-03 16:11:56 - all-mpnet-base-v2-meanpooling - nSO-x3RzUPk - done: 2733 of: 3731 - Start -  Embeddings: 1296
# 2022-12-03 16:12:37 - all-mpnet-base-v2-meanpooling - nSO-x3RzUPk - done: 2733 of: 3731 - Emb Size: torch.Size([1296, 768])
# 2022-12-03 16:12:37 - all-mpnet-base-v2-meanpooling - Xvysgf5OC5U - done: 2734 of: 3731 - Start -  Embeddings: 872
# 2022-12-03 16:13:01 - all-mpnet-base-v2-meanpooling - Xvysgf5OC5U - done: 2734 of: 3731 - Emb Size: torch.Size([872, 768])
# 2022-12-03 16:13:01 - all-mpnet-base-v2-meanpooling - nDCntQ00iDg - done: 2735 of: 3731 - Start -  Embeddings: 383
# 2022-12-03 16:13:13 - all-mpnet-base-v2-meanpooling - nDCntQ00iDg - done: 2735 of: 3731 - Emb Size: torch.Size([383, 768])
# 2022-12-03 16:13:13 - all-mpnet-base-v2-meanpooling - VYjHTqBHhB0 - done: 2736 of: 3731 - Start -  Embeddings: 667
# 2022-12-03 16:13:33 - all-mpnet-base-v2-meanpooling - VYjHTqBHhB0 - done: 2736 of: 3731 - Emb Size: torch.Size([667, 768])
# 2022-12-03 16:13:33 - all-mpnet-base-v2-meanpooling - h3OTliylE8Y - done: 2737 of: 3731 - Start -  Embeddings: 1850
# 2022-12-03 16:14:32 - all-mpnet-base-v2-meanpooling - h3OTliylE8Y - done: 2737 of: 3731 - Emb Size: torch.Size([1850, 768])
# 2022-12-03 16:14:32 - all-mpnet-base-v2-meanpooling - -RN53GIAHWA - done: 2738 of: 3731 - Start -  Embeddings: 1536
# 2022-12-03 16:15:23 - all-mpnet-base-v2-meanpooling - -RN53GIAHWA - done: 2738 of: 3731 - Emb Size: torch.Size([1536, 768])
# 2022-12-03 16:15:23 - all-mpnet-base-v2-meanpooling - TnF69kXA9h0 - done: 2739 of: 3731 - Start -  Embeddings: 1492
# 2022-12-03 16:16:09 - all-mpnet-base-v2-meanpooling - TnF69kXA9h0 - done: 2739 of: 3731 - Emb Size: torch.Size([1492, 768])
# 2022-12-03 16:16:09 - all-mpnet-base-v2-meanpooling - rpaR44CIFxY - done: 2740 of: 3731 - Start -  Embeddings: 1184
# 2022-12-03 16:16:47 - all-mpnet-base-v2-meanpooling - rpaR44CIFxY - done: 2740 of: 3731 - Emb Size: torch.Size([1184, 768])
# 2022-12-03 16:16:47 - all-mpnet-base-v2-meanpooling - xAmi8mZ81pI - done: 2741 of: 3731 - Start -  Embeddings: 1804
# 2022-12-03 16:17:44 - all-mpnet-base-v2-meanpooling - xAmi8mZ81pI - done: 2741 of: 3731 - Emb Size: torch.Size([1804, 768])
# 2022-12-03 16:17:44 - all-mpnet-base-v2-meanpooling - v7VQAhwSvZk - done: 2742 of: 3731 - Start -  Embeddings: 113
# 2022-12-03 16:17:48 - all-mpnet-base-v2-meanpooling - v7VQAhwSvZk - done: 2742 of: 3731 - Emb Size: torch.Size([113, 768])
# 2022-12-03 16:17:48 - all-mpnet-base-v2-meanpooling - Fbv8jJ_ccNI - done: 2743 of: 3731 - Start -  Embeddings: 454
# 2022-12-03 16:18:02 - all-mpnet-base-v2-meanpooling - Fbv8jJ_ccNI - done: 2743 of: 3731 - Emb Size: torch.Size([454, 768])
# 2022-12-03 16:18:02 - all-mpnet-base-v2-meanpooling - tQpDzR4WeuU - done: 2744 of: 3731 - Start -  Embeddings: 716
# 2022-12-03 16:18:20 - all-mpnet-base-v2-meanpooling - tQpDzR4WeuU - done: 2744 of: 3731 - Emb Size: torch.Size([716, 768])
# 2022-12-03 16:18:20 - all-mpnet-base-v2-meanpooling - yfD8Nj4Xa2I - done: 2745 of: 3731 - Start -  Embeddings: 502
# 2022-12-03 16:18:34 - all-mpnet-base-v2-meanpooling - yfD8Nj4Xa2I - done: 2745 of: 3731 - Emb Size: torch.Size([502, 768])
# 2022-12-03 16:18:34 - all-mpnet-base-v2-meanpooling - LLOLKQjmSck - done: 2746 of: 3731 - Start -  Embeddings: 647
# 2022-12-03 16:18:55 - all-mpnet-base-v2-meanpooling - LLOLKQjmSck - done: 2746 of: 3731 - Emb Size: torch.Size([647, 768])
# 2022-12-03 16:18:55 - all-mpnet-base-v2-meanpooling - 21JshfFFH7Q - done: 2747 of: 3731 - Start -  Embeddings: 1080
# 2022-12-03 16:19:24 - all-mpnet-base-v2-meanpooling - 21JshfFFH7Q - done: 2747 of: 3731 - Emb Size: torch.Size([1080, 768])
# 2022-12-03 16:19:24 - all-mpnet-base-v2-meanpooling - TJnsrvT7FQg - done: 2748 of: 3731 - Start -  Embeddings: 1300
# 2022-12-03 16:20:04 - all-mpnet-base-v2-meanpooling - TJnsrvT7FQg - done: 2748 of: 3731 - Emb Size: torch.Size([1300, 768])
# 2022-12-03 16:20:04 - all-mpnet-base-v2-meanpooling - 94kQCoVzJrQ - done: 2749 of: 3731 - Start -  Embeddings: 770
# 2022-12-03 16:20:26 - all-mpnet-base-v2-meanpooling - 94kQCoVzJrQ - done: 2749 of: 3731 - Emb Size: torch.Size([770, 768])
# 2022-12-03 16:20:26 - all-mpnet-base-v2-meanpooling - A5-zTvUlW5M - done: 2750 of: 3731 - Start -  Embeddings: 568
# 2022-12-03 16:20:43 - all-mpnet-base-v2-meanpooling - A5-zTvUlW5M - done: 2750 of: 3731 - Emb Size: torch.Size([568, 768])
# 2022-12-03 16:20:43 - all-mpnet-base-v2-meanpooling - joq0ZVA6JFA - done: 2751 of: 3731 - Start -  Embeddings: 1032
# 2022-12-03 16:21:17 - all-mpnet-base-v2-meanpooling - joq0ZVA6JFA - done: 2751 of: 3731 - Emb Size: torch.Size([1032, 768])
# 2022-12-03 16:21:17 - all-mpnet-base-v2-meanpooling - _K_WMbGddrI - done: 2752 of: 3731 - Start -  Embeddings: 850
# 2022-12-03 16:21:45 - all-mpnet-base-v2-meanpooling - _K_WMbGddrI - done: 2752 of: 3731 - Emb Size: torch.Size([850, 768])
# 2022-12-03 16:21:45 - all-mpnet-base-v2-meanpooling - GE2upZ6R8iA - done: 2753 of: 3731 - Start -  Embeddings: 1635
# 2022-12-03 16:22:36 - all-mpnet-base-v2-meanpooling - GE2upZ6R8iA - done: 2753 of: 3731 - Emb Size: torch.Size([1635, 768])
# 2022-12-03 16:22:36 - all-mpnet-base-v2-meanpooling - 4ZSJfQEDHPQ - done: 2754 of: 3731 - Start -  Embeddings: 732
# 2022-12-03 16:22:57 - all-mpnet-base-v2-meanpooling - 4ZSJfQEDHPQ - done: 2754 of: 3731 - Emb Size: torch.Size([732, 768])
# 2022-12-03 16:22:57 - all-mpnet-base-v2-meanpooling - zSgIA8vf1zk - done: 2755 of: 3731 - Start -  Embeddings: 54
# 2022-12-03 16:22:59 - all-mpnet-base-v2-meanpooling - zSgIA8vf1zk - done: 2755 of: 3731 - Emb Size: torch.Size([54, 768])
# 2022-12-03 16:22:59 - all-mpnet-base-v2-meanpooling - QynBEzLt7Vo - done: 2756 of: 3731 - Start -  Embeddings: 1419
# 2022-12-03 16:23:41 - all-mpnet-base-v2-meanpooling - QynBEzLt7Vo - done: 2756 of: 3731 - Emb Size: torch.Size([1419, 768])
# 2022-12-03 16:23:41 - all-mpnet-base-v2-meanpooling - h4_WWkyJYrw - done: 2757 of: 3731 - Start -  Embeddings: 1198
# 2022-12-03 16:24:15 - all-mpnet-base-v2-meanpooling - h4_WWkyJYrw - done: 2757 of: 3731 - Emb Size: torch.Size([1198, 768])
# 2022-12-03 16:24:15 - all-mpnet-base-v2-meanpooling - FndlmpAxZ2s - done: 2758 of: 3731 - Start -  Embeddings: 1786
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e92d5fe234f5> in <module>
#      56         # Create Embedding
#      57         with torch.no_grad():
# ---> 58             model_output = model(**encoded_input)
#      59
#      60         # MAX or MEAN pooling
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     552         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     553         embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 554         encoder_outputs = self.encoder(
#     555             embedding_output,
#     556             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     339                 all_hidden_states = all_hidden_states + (hidden_states,)
#     340
# --> 341             layer_outputs = layer_module(
#     342                 hidden_states,
#     343                 attention_mask,
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     309
#     310         intermediate_output = self.intermediate(attention_output)
# --> 311         layer_output = self.output(intermediate_output, attention_output)
#     312         outputs = (layer_output,) + outputs
#     313         return outputs
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, input_tensor)
#     276
#     277     def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 278         hidden_states = self.dense(hidden_states)
#     279         hidden_states = self.dropout(hidden_states)
#     280         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
