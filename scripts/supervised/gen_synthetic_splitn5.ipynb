# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Authenticate to access cloud bucket
from google.colab import auth
auth.authenticate_user()

# %%
import pandas as pd
import numpy as np
import torch
import os
from tqdm import tqdm
import ast
import json
import random
from tensorflow.keras.utils import pad_sequences

path = '/content/drive/MyDrive/nlp_podcast_segmentation/'
yt_path = path + 'data/YouTube/'
splits = 'yt_scripts_segments_split_n5_111422'
pooling = 'all-MiniLM-L6-v2-meanpooling' # all-MiniLM-L6-v2-meanpooling or #stsb-mpnet-base-v2-meanpooling
embed_path = yt_path + f'embeddings/{splits}/{pooling}/'

# %% [markdown]
# ## Set params

# %%
# Set params
continue_run = True
max_sequence = 350 # no. sentences per synth episode <---- maybe match up with z-stat in test set?
synth_eps = 50000 # no. synthetic episodes to generates
seg_batch = 100 # no. segments to use for each synthetic episode (max for 100 sentences is ~13 segments)
num_segs = 27855 # number of records in file (from seg_df script)
save_every = 1000 # save dicts out in increments
num_parallel = 1000 # how many episodes to build fro mthe seg_batch

# %% [markdown]
# ## Load Splits (from gen_seg_df.py)

# %%
if not continue_run:
  print("Load splits")
  # Load episode df, then merge embedding file paths
  df = pd.read_pickle(yt_path+'yt_scripts_segments_split_n5_111422_slimcols.csv')
  emb_df = pd.DataFrame({'Video_Id': [x[:-3] for x in os.listdir(embed_path)],
                        'emb_file': os.listdir(embed_path),})
  vids = pd.merge(df, emb_df, on='Video_Id', how='inner')

  # Get rid of episodes with only a few segments
  vids['num_segments'] = vids['Transition_Labels'].apply(lambda x: sum(x))
  vids = vids.loc[vids['num_segments'] > 4, ].copy()

  ## Split into train and test sets
  mask = np.load(f"{embed_path}split_mask.npy")
  train = vids[mask]
  test = vids[~mask]

# %% [markdown]
# ## Save Initial Train, Test Set and Partition Dicts

# %%
def pt_to_npy(ids, max_sequence):
  for id in tqdm(ids):
    emb = torch.load(embed_path + id + '.pt').numpy().tolist() # load
    # Truncate, or Pad if num sentences < max_seq
    if len(emb) >= max_sequence:
      pad = emb[:max_sequence]
    else:
      pad = emb.copy()
      for i in range(max_sequence-len(emb)):
        pad.append(np.zeros(len(emb[0])))
    np.save(f"{embed_path}train_test/{id}.npy", pad) # save to npy


def save_dicts(train_ids, test_ids, all_ids, all_labs):
  partitions = {'train': train_ids, 'test': test_ids}
  labels = dict(zip(all_ids, all_labs))
  with open(f"{embed_path}train_test/partitions.json", 'w') as fp:
      json.dump(partitions, fp)
  with open(f"{embed_path}train_test/labels.json", 'w') as fp:
      json.dump(labels, fp)


def load_dicts():
  with open(f"{embed_path}train_test/partitions.json", 'r') as f:
    partitions = json.load(f)
  with open(f"{embed_path}train_test/labels.json", 'r') as f:
    labels = json.load(f)

  train_ids = partitions['train']
  test_ids = partitions['test']
  all_ids = list(labels.keys())
  all_labs = list(labels.values())

  return train_ids, test_ids, all_ids, all_labs

# %%
if not os.path.exists(f"{embed_path}train_test/"):
  os.mkdir(f"{embed_path}train_test/")
  print("Creating new directory")
else:
  print("Directory exists")
# Out:
# Directory exists

# %%
if continue_run: # resuming where we left off
  print({"Loading dictionaries from previous run"})
  # Reload partitions, labels dicts
  train_ids, test_ids, all_ids, all_labs = load_dicts()

  # Get num synth episodes remaining
  synth_gen = len([x for x in train_ids if 'synth' in x])
  synth_eps = synth_eps - synth_gen
  print(f"Synth eps generated: {synth_gen}, num remaining: {synth_eps}")

else:
  print("Beginning new run, saving ids, embeddings, labels for initial splits")
  # Save test embeddings to numpy files
  pt_to_npy(test['Video_Id'].values, max_sequence)
  pt_to_npy(train['Video_Id'].values, max_sequence)
  synth_gen = 0
  print(f"Synth eps generated: {synth_gen}, num remaining: {synth_eps}")

  ## Init partition dfs
  # Track Ids
  train_ids = []
  all_ids = []
  test_ids = test['Video_Id'].tolist()
  train_ids.extend(train['Video_Id'].values)
  all_ids.extend(train['Video_Id'].values)
  all_ids.extend(test['Video_Id'].values)

  # Track labels
  all_labs = []
  train_labs = pad_sequences(train['Transition_Labels'].values, maxlen=max_sequence, 
                        dtype='uint8', padding="post", truncating="post").tolist()
  test_labs = pad_sequences(test['Transition_Labels'].values, maxlen=max_sequence, 
                        dtype='uint8', padding="post", truncating="post").tolist()
  all_labs.extend(train_labs)
  all_labs.extend(test_labs)

  # Save initial partition, label dicts
  save_dicts(train_ids, test_ids, all_ids, all_labs)
# Out:
# {'Loading dictionaries from previous run'}
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-5d727cbad8cd> in <module>
#       2   print({"Loading dictionaries from previous run"})
#       3   # Reload partitions, labels dicts
# ----> 4   train_ids, test_ids, all_ids, all_labs = load_dicts()
#       5
#       6   # Get num synth episodes remaining
#
# <ipython-input-6-a130f5dab362> in load_dicts()
#      22
#      23 def load_dicts():
# ---> 24   with open(f"{embed_path}train_test/partitions.json", 'r') as f:
#      25     partitions = json.load(f)
#      26   with open(f"{embed_path}train_test/labels.json", 'r') as f:
#
# OSError: [Errno 5] Input/output error: '/content/drive/MyDrive/nlp_podcast_segmentation/data/YouTube/embeddings/yt_scripts_segments_split_n5_111422/all-MiniLM-L6-v2-meanpooling/train_test/partitions.json'

# %%
remaining = [x for x in train_ids if f"{x}.npy" in os.listdir(f"{embed_path}train_test")]
print(len(remaining))

# %% [markdown]
# ## Create Synthetic Train Records

# %%
# Loop to create synthetic episodes
c_list = [] # track num segs used for each synth episode
for i in tqdm(range(round(synth_eps/num_parallel))):
  # load and shuffle segments
  skip = sorted(random.sample(range(1, num_segs), num_segs-seg_batch))
  batch = pd.read_csv(embed_path + "seg_df.csv", header=0, skiprows=skip) # load in a random subset of segments
  batch['seg_labels'] = batch['seg_labels'].apply(lambda x: ast.literal_eval(x))
  batch['seg_embs'] = batch['seg_embs'].apply(lambda x: ast.literal_eval(x))
  
  # use the loaded segments multiple times by shuffling and reconcatenating
  # to save runtime
  for z in range(num_parallel):
    synth_id = synth_gen+(num_parallel*i)+z
    shuffled = batch.sample(frac=1) # shuffle once more
    shuffled.reset_index(inplace=True, drop=True)

    # loop through segments, combining them until max length reached
    ne_emb = []
    ne_lab = []
    c = 0
    while len(ne_lab) < max_sequence:
      # get one row sents, labels, append to new ep
      ne_lab.extend(shuffled.loc[c, 'seg_labels'])
      ne_emb.extend(shuffled.loc[c, 'seg_embs'])
      c += 1
    c_list.append(c)

    # Save to partition dict
    np.save(f"{embed_path}train_test/synth_{synth_id}.npy", ne_emb[:max_sequence])
    train_ids.append(f"synth_{synth_id}")
    all_ids.append(f"synth_{synth_id}")
    all_labs.append([int(x) for x in ne_lab[:max_sequence]])

    # Save partition dicts periodically
    if ((synth_id+1)%save_every==0):
      save_dicts(train_ids, test_ids, all_ids, all_labs)
      #print(f"\nSaving latest batch of dicts out: {synth_id}")

save_dicts(train_ids, test_ids, all_ids, all_labs)
print(f"\nSaving final batch of dicts out: {synth_id}")
print(f"\nMax segs needed: {np.max(c_list)}")

# %%
# push to cloud storage
# !gsutil -m cp -r -n /content/drive/MyDrive/nlp_podcast_segmentation/data/YouTube/embeddings/yt_scripts_segments_split_n5_111422/all-MiniLM-L6-v2-meanpooling/train_test/ gs://podcast_episodes/
# Out:
# Streaming output truncated to the last 5000 lines.
# Skipping existing item: gs://podcast_episodes/train_test/synth_45000.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_44997.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45003.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45006.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45007.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45004.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45002.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45005.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45009.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45008.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45010.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45011.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45012.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45015.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45013.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45014.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45017.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45018.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45016.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45021.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45020.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45019.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45022.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45023.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45024.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45025.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45026.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45028.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45027.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45029.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45031.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45030.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45032.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45033.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45035.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45034.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45036.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45038.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45037.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45039.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45042.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45040.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45041.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45044.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45043.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45045.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45046.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45048.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45047.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45049.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45050.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45052.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45051.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45054.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45053.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45055.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45056.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45057.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45058.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45059.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45061.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45062.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45060.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45063.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45064.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45065.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45066.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45067.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45068.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45069.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45071.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45070.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45072.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45073.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45074.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45075.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45077.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45076.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45078.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45079.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45080.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45081.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45082.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45083.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45084.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45088.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45085.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45089.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45086.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45087.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45090.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45091.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45092.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45093.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45096.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45097.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45095.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45098.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45094.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45100.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45099.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45102.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45101.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45103.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45104.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45106.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45107.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45108.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45105.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45112.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45111.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45110.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45113.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45109.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45114.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45115.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45116.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45117.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45118.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45122.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45119.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45121.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45123.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45120.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45124.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45127.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45126.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45125.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45128.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45129.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45131.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45130.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45133.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45132.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45134.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45136.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45137.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45139.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45138.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45135.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45140.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45143.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45141.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45142.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45144.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45146.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45145.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45147.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45148.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45149.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45150.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45151.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45152.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45154.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45153.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45155.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45156.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45157.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45158.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45161.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45159.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45160.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45163.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45162.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45164.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45165.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45167.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45168.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45166.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45170.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45171.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45169.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45174.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45172.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45173.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45175.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45176.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45177.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_45180.npy
# Skipping existing item: gs://podcast_episodes/train_test/synth_