# %% [markdown]
# ## Handle Files

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# # Authenticate to access cloud bucket
# from google.colab import auth
# auth.authenticate_user()

# #create a LOCAL directory in /content/  so you can move stuff from bucket to local
# !mkdir /content/nlp_podcast_episodes
# # # copy from google bucket to local directory
# !gsutil -m -q cp -r gs://podcast_episodes/ /content/nlp_podcast_episodes

# %% [markdown]
# ## Imports and Paths

# %%
import pandas as pd
import numpy as np
from tensorflow import convert_to_tensor
from tensorflow.keras import layers
from tensorflow.keras.metrics import Accuracy, Recall
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Bidirectional
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
import json
import sys

path = '/content/drive/MyDrive/nlp_podcast_segmentation/'
yt_path = path + 'data/YouTube/'
splits = 'yt_scripts_segments_split_n5_111422'
pooling = 'all-MiniLM-L6-v2-meanpooling' # all-MiniLM-L6-v2-meanpooling or #stsb-mpnet-base-v2-meanpooling
embed_path = yt_path + f'embeddings/{splits}/{pooling}/'
dev_dir =  path + 'scripts/john/supervised/'
train_test_path = '/content/nlp_podcast_episodes/podcast_episodes/'

sys.path.append(dev_dir)
from data_loader import DataGenerator

# %%
# Set params
max_sequence = 100
embed_dim = 384
batch_size = 1024

# %% [markdown]
# ## Data loaders

# %%
# Parameters
params = {'input_dim': (max_sequence, embed_dim),
          'output_dim': max_sequence,
          'batch_size': batch_size,
          'shuffle': True}

# Datasets
with open(f"{embed_path}partitions.json", 'r') as f:
  partitions = json.load(f)
with open(f"{embed_path}labels.json", 'r') as f:
  labels = json.load(f)

# Generators
training_generator = DataGenerator(partitions['train'], labels, **params)
test_generator = DataGenerator(partitions['test'], labels, **params)

# %%
# Prepare test inputs, labels
test_size = len(partitions['test'])
X_test = np.empty((test_size, max_sequence, embed_dim))
y_test = np.empty((test_size, max_sequence), dtype=int)

for i, ID in enumerate(partitions['test']):
  X_test[i] = np.load(f"{train_test_path}{ID}.npy")
  y_test[i] = np.array(labels[ID], dtype='uint8')

# %%
# Get pos and neg labels
pos = 0
neg = 0

# Loop through batches to get counts
for ID in partitions['train']:
  pos += np.sum(labels[ID])
  neg += len(labels[ID]) - np.sum(labels[ID])

# Get total
total = pos + neg
print(f"Pos rate: {pos/total}, Neg rate: {neg/total}, Total: {total}")

# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
initial_bias = np.log([pos/neg])
weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}
print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Pos rate: 0.048399046289834845, Neg rate: 0.9516009537101652, Total: 5158800
# Weight for class 0: 0.53
# Weight for class 1: 10.33

# %% [markdown]
# ## Baseline Model (Simple RNN)

# %%
def create_rnn_model(max_sequence_length=1000,
                     embed_dim = 384,
                     hidden_dim=64,
                     dropout=0.10,
                     learning_rate=0.001,
                     output_bias=np.log(0.05/0.95),
                     loss=tf.keras.losses.BinaryCrossentropy(from_logits=True)
                     ):

  ## Build model
  output_bias = tf.keras.initializers.Constant(output_bias)
  input_layer = tf.keras.layers.Input(
      shape=(max_sequence_length, embed_dim), dtype='float32')
  lstm1 = LSTM(
      hidden_dim, return_sequences=True, activation='relu', name='rnn_layer_1'
      )(input_layer)
  lstm2 = LSTM(
      hidden_dim, return_sequences=True, activation='relu', name='rnn_layer_2'
      )(lstm1)
  #drop1 = tf.keras.layers.Dropout(dropout)(lstm2)
  dense1 = tf.keras.layers.Dense(128, activation='relu', name='dense_1')(lstm2)
  dense2 = tf.keras.layers.Dense(32, activation='relu', name='dense_2')(dense1)                  
  output = tf.keras.layers.Dense(1, activation='sigmoid',
                                 bias_initializer=output_bias,
                                 name='segment_classifier')(dense2)
  
  rnn_model = tf.keras.models.Model(inputs=input_layer, outputs=[output])
  rnn_model.compile(loss=loss,
                    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate),
                    metrics=[tf.keras.metrics.Recall(), 
                             tf.keras.metrics.Accuracy()]
                    )

  ### END YOUR CODE
  return rnn_model

# %%
# Eventual loss function strucutre
def my_loss(weight):
  def weighted_cross_entropy_with_logits(labels, logits):
    labels = tf.cast(labels, 'float32')
    #logits = tf.where(tf.less(logits, 0), 0., logits) # prevents odd error of pred < 0
    loss = tf.nn.weighted_cross_entropy_with_logits(
        labels, logits, weight
    )
    return loss
  return weighted_cross_entropy_with_logits

## LR Scheduler
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=4,
    verbose=1,
    mode="auto",
    min_delta=0.0001)

# %%
rnn_model = create_rnn_model(max_sequence_length=max_sequence,
                              embed_dim=embed_dim,
                              hidden_dim=128,
                              dropout=0.05,
                              learning_rate=0.004,
                              output_bias=initial_bias,
                              loss=my_loss(weight=weight_for_1*4)
                              )
rnn_model.summary()
# Out:
# WARNING:tensorflow:Layer rnn_layer_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer rnn_layer_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 384)]        0
#
#  rnn_layer_1 (LSTM)          (None, 100, 128)          262656
#
#  rnn_layer_2 (LSTM)          (None, 100, 128)          131584
#
#  dense_1 (Dense)             (None, 100, 128)          16512
#
#  dense_2 (Dense)             (None, 100, 32)           4128
#
#  segment_classifier (Dense)  (None, 100, 1)            33
#
# =================================================================
# Total params: 414,913
# Trainable params: 414,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
rnn_history = rnn_model.fit(training_generator,
                            validation_data=test_generator,
                            epochs=200,
                            callbacks=[reduce_lr],
                            )
# Out:
# Epoch 1/200
# 50/50 [==============================] - 178s 3s/step - loss: 1.8975 - recall: 0.5177 - accuracy: 5.6191e-04 - val_loss: 1.7749 - val_recall: 0.5880 - val_accuracy: 0.0014 - lr: 0.0040
# Epoch 2/200
# 50/50 [==============================] - 178s 4s/step - loss: 1.6507 - recall: 0.7650 - accuracy: 0.0069 - val_loss: 1.7631 - val_recall: 0.4598 - val_accuracy: 0.0042 - lr: 0.0040
# Epoch 3/200
# 50/50 [==============================] - 173s 3s/step - loss: 1.5515 - recall: 0.7951 - accuracy: 0.0167 - val_loss: 1.7756 - val_recall: 0.3662 - val_accuracy: 0.0037 - lr: 0.0040
# Epoch 4/200
# 50/50 [==============================] - 170s 3s/step - loss: 1.5185 - recall: 0.8167 - accuracy: 0.0200 - val_loss: 1.7768 - val_recall: 0.3115 - val_accuracy: 0.0028 - lr: 0.0040
# Epoch 5/200
# 50/50 [==============================] - 166s 3s/step - loss: 1.5008 - recall: 0.8311 - accuracy: 0.0223 - val_loss: 1.8084 - val_recall: 0.2863 - val_accuracy: 0.0033 - lr: 0.0040
# Epoch 6/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4882 - recall: 0.8422 - accuracy: 0.0235
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# 50/50 [==============================] - 165s 3s/step - loss: 1.4882 - recall: 0.8422 - accuracy: 0.0235 - val_loss: 1.7827 - val_recall: 0.2708 - val_accuracy: 0.0030 - lr: 0.0040
# Epoch 7/200
# 50/50 [==============================] - 170s 3s/step - loss: 1.4774 - recall: 0.8502 - accuracy: 0.0242 - val_loss: 1.7920 - val_recall: 0.2978 - val_accuracy: 0.0034 - lr: 0.0020
# Epoch 8/200
# 50/50 [==============================] - 165s 3s/step - loss: 1.4724 - recall: 0.8539 - accuracy: 0.0248 - val_loss: 1.8023 - val_recall: 0.2740 - val_accuracy: 0.0034 - lr: 0.0020
# Epoch 9/200
# 50/50 [==============================] - 166s 3s/step - loss: 1.4681 - recall: 0.8576 - accuracy: 0.0257 - val_loss: 1.8018 - val_recall: 0.2502 - val_accuracy: 0.0033 - lr: 0.0020
# Epoch 10/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4640 - recall: 0.8608 - accuracy: 0.0264
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 50/50 [==============================] - 171s 3s/step - loss: 1.4640 - recall: 0.8608 - accuracy: 0.0264 - val_loss: 1.7959 - val_recall: 0.2681 - val_accuracy: 0.0037 - lr: 0.0020
# Epoch 11/200
# 50/50 [==============================] - 167s 3s/step - loss: 1.4591 - recall: 0.8636 - accuracy: 0.0270 - val_loss: 1.7784 - val_recall: 0.2918 - val_accuracy: 0.0039 - lr: 0.0010
# Epoch 12/200
# 50/50 [==============================] - 167s 3s/step - loss: 1.4571 - recall: 0.8657 - accuracy: 0.0276 - val_loss: 1.7865 - val_recall: 0.2806 - val_accuracy: 0.0039 - lr: 0.0010
# Epoch 13/200
# 50/50 [==============================] - 169s 3s/step - loss: 1.4552 - recall: 0.8673 - accuracy: 0.0281 - val_loss: 1.7993 - val_recall: 0.2667 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 14/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4532 - recall: 0.8688 - accuracy: 0.0286
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 [==============================] - 167s 3s/step - loss: 1.4532 - recall: 0.8688 - accuracy: 0.0286 - val_loss: 1.7723 - val_recall: 0.2922 - val_accuracy: 0.0044 - lr: 0.0010
# Epoch 15/200
# 50/50 [==============================] - 166s 3s/step - loss: 1.4514 - recall: 0.8707 - accuracy: 0.0291 - val_loss: 1.7990 - val_recall: 0.2674 - val_accuracy: 0.0043 - lr: 5.0000e-04
# Epoch 16/200
# 50/50 [==============================] - 165s 3s/step - loss: 1.4503 - recall: 0.8715 - accuracy: 0.0294 - val_loss: 1.7827 - val_recall: 0.2706 - val_accuracy: 0.0044 - lr: 5.0000e-04
# Epoch 17/200
# 50/50 [==============================] - 167s 3s/step - loss: 1.4490 - recall: 0.8724 - accuracy: 0.0298 - val_loss: 1.7996 - val_recall: 0.2771 - val_accuracy: 0.0048 - lr: 5.0000e-04
# Epoch 18/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4482 - recall: 0.8737 - accuracy: 0.0302
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 [==============================] - 163s 3s/step - loss: 1.4482 - recall: 0.8737 - accuracy: 0.0302 - val_loss: 1.7846 - val_recall: 0.2672 - val_accuracy: 0.0045 - lr: 5.0000e-04
# Epoch 19/200
# 50/50 [==============================] - 162s 3s/step - loss: 1.4471 - recall: 0.8748 - accuracy: 0.0305 - val_loss: 1.8176 - val_recall: 0.2699 - val_accuracy: 0.0049 - lr: 2.5000e-04
# Epoch 20/200
# 50/50 [==============================] - 166s 3s/step - loss: 1.4463 - recall: 0.8753 - accuracy: 0.0307 - val_loss: 1.8006 - val_recall: 0.2704 - val_accuracy: 0.0049 - lr: 2.5000e-04
# Epoch 21/200
# 50/50 [==============================] - 167s 3s/step - loss: 1.4457 - recall: 0.8756 - accuracy: 0.0309 - val_loss: 1.7854 - val_recall: 0.2687 - val_accuracy: 0.0048 - lr: 2.5000e-04
# Epoch 22/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4451 - recall: 0.8762 - accuracy: 0.0312
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 166s 3s/step - loss: 1.4451 - recall: 0.8762 - accuracy: 0.0312 - val_loss: 1.8158 - val_recall: 0.2631 - val_accuracy: 0.0050 - lr: 2.5000e-04
# Epoch 23/200
# 50/50 [==============================] - 169s 3s/step - loss: 1.4444 - recall: 0.8767 - accuracy: 0.0314 - val_loss: 1.7608 - val_recall: 0.2797 - val_accuracy: 0.0052 - lr: 1.2500e-04
# Epoch 24/200
# 50/50 [==============================] - 169s 3s/step - loss: 1.4443 - recall: 0.8770 - accuracy: 0.0315 - val_loss: 1.7992 - val_recall: 0.2709 - val_accuracy: 0.0052 - lr: 1.2500e-04
# Epoch 25/200
# 50/50 [==============================] - 167s 3s/step - loss: 1.4439 - recall: 0.8773 - accuracy: 0.0316 - val_loss: 1.8123 - val_recall: 0.2687 - val_accuracy: 0.0052 - lr: 1.2500e-04
# Epoch 26/200
# 50/50 [==============================] - 163s 3s/step - loss: 1.4436 - recall: 0.8776 - accuracy: 0.0317 - val_loss: 1.8152 - val_recall: 0.2622 - val_accuracy: 0.0051 - lr: 1.2500e-04
# Epoch 27/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4434 - recall: 0.8778 - accuracy: 0.0318
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 162s 3s/step - loss: 1.4434 - recall: 0.8778 - accuracy: 0.0318 - val_loss: 1.8122 - val_recall: 0.2636 - val_accuracy: 0.0050 - lr: 1.2500e-04
# Epoch 28/200
# 50/50 [==============================] - 164s 3s/step - loss: 1.4432 - recall: 0.8781 - accuracy: 0.0319 - val_loss: 1.8112 - val_recall: 0.2750 - val_accuracy: 0.0054 - lr: 6.2500e-05
# Epoch 29/200
# 50/50 [==============================] - 161s 3s/step - loss: 1.4430 - recall: 0.8781 - accuracy: 0.0320 - val_loss: 1.7888 - val_recall: 0.2631 - val_accuracy: 0.0050 - lr: 6.2500e-05
# Epoch 30/200
# 50/50 [==============================] - 160s 3s/step - loss: 1.4429 - recall: 0.8783 - accuracy: 0.0321 - val_loss: 1.8061 - val_recall: 0.2716 - val_accuracy: 0.0052 - lr: 6.2500e-05
# Epoch 31/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4427 - recall: 0.8785 - accuracy: 0.0321
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 [==============================] - 162s 3s/step - loss: 1.4427 - recall: 0.8785 - accuracy: 0.0321 - val_loss: 1.7979 - val_recall: 0.2614 - val_accuracy: 0.0050 - lr: 6.2500e-05
# Epoch 32/200
# 50/50 [==============================] - 166s 3s/step - loss: 1.4424 - recall: 0.8786 - accuracy: 0.0322 - val_loss: 1.8046 - val_recall: 0.2719 - val_accuracy: 0.0056 - lr: 3.1250e-05
# Epoch 33/200
# 50/50 [==============================] - 162s 3s/step - loss: 1.4427 - recall: 0.8787 - accuracy: 0.0322 - val_loss: 1.8057 - val_recall: 0.2725 - val_accuracy: 0.0054 - lr: 3.1250e-05
# Epoch 34/200
# 50/50 [==============================] - 165s 3s/step - loss: 1.4423 - recall: 0.8789 - accuracy: 0.0323 - val_loss: 1.7874 - val_recall: 0.2679 - val_accuracy: 0.0053 - lr: 3.1250e-05
# Epoch 35/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4425 - recall: 0.8787 - accuracy: 0.0323
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 50/50 [==============================] - 165s 3s/step - loss: 1.4425 - recall: 0.8787 - accuracy: 0.0323 - val_loss: 1.7972 - val_recall: 0.2677 - val_accuracy: 0.0054 - lr: 3.1250e-05
# Epoch 36/200
# 50/50 [==============================] - 164s 3s/step - loss: 1.4423 - recall: 0.8788 - accuracy: 0.0323 - val_loss: 1.8007 - val_recall: 0.2685 - val_accuracy: 0.0055 - lr: 1.5625e-05
# Epoch 37/200
# 50/50 [==============================] - 166s 3s/step - loss: 1.4424 - recall: 0.8788 - accuracy: 0.0323 - val_loss: 1.8007 - val_recall: 0.2681 - val_accuracy: 0.0054 - lr: 1.5625e-05
# Epoch 38/200
# 50/50 [==============================] - 166s 3s/step - loss: 1.4423 - recall: 0.8788 - accuracy: 0.0324 - val_loss: 1.8068 - val_recall: 0.2699 - val_accuracy: 0.0054 - lr: 1.5625e-05
# Epoch 39/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4422 - recall: 0.8790 - accuracy: 0.0324
# Epoch 39: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 50/50 [==============================] - 166s 3s/step - loss: 1.4422 - recall: 0.8790 - accuracy: 0.0324 - val_loss: 1.8081 - val_recall: 0.2622 - val_accuracy: 0.0054 - lr: 1.5625e-05
# Epoch 40/200
# 50/50 [==============================] - 165s 3s/step - loss: 1.4422 - recall: 0.8789 - accuracy: 0.0324 - val_loss: 1.8013 - val_recall: 0.2584 - val_accuracy: 0.0051 - lr: 7.8125e-06
# Epoch 41/200
# 50/50 [==============================] - 162s 3s/step - loss: 1.4421 - recall: 0.8789 - accuracy: 0.0324 - val_loss: 1.7913 - val_recall: 0.2605 - val_accuracy: 0.0053 - lr: 7.8125e-06
# Epoch 42/200
# 50/50 [==============================] - 161s 3s/step - loss: 1.4422 - recall: 0.8789 - accuracy: 0.0324 - val_loss: 1.8044 - val_recall: 0.2717 - val_accuracy: 0.0054 - lr: 7.8125e-06
# Epoch 43/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4422 - recall: 0.8789 - accuracy: 0.0324
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 50/50 [==============================] - 161s 3s/step - loss: 1.4422 - recall: 0.8789 - accuracy: 0.0324 - val_loss: 1.7841 - val_recall: 0.2607 - val_accuracy: 0.0051 - lr: 7.8125e-06
# Epoch 44/200
# 50/50 [==============================] - 163s 3s/step - loss: 1.4419 - recall: 0.8791 - accuracy: 0.0324 - val_loss: 1.7931 - val_recall: 0.2698 - val_accuracy: 0.0054 - lr: 3.9063e-06
# Epoch 45/200
# 50/50 [==============================] - 161s 3s/step - loss: 1.4421 - recall: 0.8790 - accuracy: 0.0324 - val_loss: 1.8229 - val_recall: 0.2588 - val_accuracy: 0.0053 - lr: 3.9063e-06
# Epoch 46/200
# 50/50 [==============================] - 165s 3s/step - loss: 1.4423 - recall: 0.8791 - accuracy: 0.0325 - val_loss: 1.7913 - val_recall: 0.2576 - val_accuracy: 0.0050 - lr: 3.9063e-06
# Epoch 47/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4419 - recall: 0.8790 - accuracy: 0.0324
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 50/50 [==============================] - 165s 3s/step - loss: 1.4419 - recall: 0.8790 - accuracy: 0.0324 - val_loss: 1.7898 - val_recall: 0.2561 - val_accuracy: 0.0050 - lr: 3.9063e-06
# Epoch 48/200
# 50/50 [==============================] - 167s 3s/step - loss: 1.4424 - recall: 0.8791 - accuracy: 0.0325 - val_loss: 1.8073 - val_recall: 0.2664 - val_accuracy: 0.0054 - lr: 1.9531e-06
# Epoch 49/200
# 50/50 [==============================] - 166s 3s/step - loss: 1.4424 - recall: 0.8790 - accuracy: 0.0325 - val_loss: 1.7925 - val_recall: 0.2689 - val_accuracy: 0.0054 - lr: 1.9531e-06
# Epoch 50/200
# 50/50 [==============================] - 165s 3s/step - loss: 1.4422 - recall: 0.8789 - accuracy: 0.0325 - val_loss: 1.7879 - val_recall: 0.2675 - val_accuracy: 0.0054 - lr: 1.9531e-06
# Epoch 51/200
# 50/50 [==============================] - ETA: 0s - loss: 1.4422 - recall: 0.8790 - accuracy: 0.0325
# Epoch 51: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 50/50 [==============================] - 170s 3s/step - loss: 1.4422 - recall: 0.8790 - accuracy: 0.0325 - val_loss: 1.8098 - val_recall: 0.2643 - val_accuracy: 0.0055 - lr: 1.9531e-06
# Epoch 52/200
# 50/50 [==============================] - 166s 3s/step - loss: 1.4420 - recall: 0.8791 - accuracy: 0.0325 - val_loss: 1.8071 - val_recall: 0.2639 - val_accuracy: 0.0055 - lr: 9.7656e-07
# Epoch 53/200
# 50/50 [==============================] - 167s 3s/step - loss: 1.4421 - recall: 0.8790 - accuracy: 0.0325 - val_loss: 1.7658 - val_recall: 0.2770 - val_accuracy: 0.0054 - lr: 9.7656e-07
# Epoch 54/200
# 50/50 [==============================] - 168s 3s/step - loss: 1.4421 - recall: 0.8790 - accuracy: 0.0325 - val_loss: 1.7990 - val_recall: 0.2632 - val_accuracy: 0.0053 - lr: 9.7656e-07
# Epoch 55/200
# 39/50 [======================>.......] - ETA: 33s - loss: 1.4420 - recall: 0.8791 - accuracy: 0.0325
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-11-868cf0ace880>", line 4, in <module>
#     callbacks=[reduce_lr],
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1409, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py", line 915, in __call__
#     result = self._call(*args, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py", line 947, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 2454, in __call__
#     filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 1861, in _call_flat
#     ctx, args, cancellation_manager=cancellation_manager))
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 502, in call
#     ctx=ctx)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py", line 55, in quick_execute
#     inputs, attrs, num_outputs)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.7/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/usr/lib/python3.7/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/usr/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/usr/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Evaluate

# %%
def average_sentences(topic_list):
  '''
  Counts the number of sentences between topics
  input: topic labels
  returns: average number of sentences between topics
  '''

  idx = 0
  N = len(topic_list)
  sentence_counts = []
  count = 0

  while(idx < N):
    if(topic_list[idx] == 1):
      sentence_counts.append(count)
      count = 0

    count += 1
    idx += 1

  
  if len(sentence_counts) == 0:
    return 0
    
  return sum(sentence_counts) / len(sentence_counts)

# Evaluates PK
def evaluate_pk(pred, act, k=5):
  idx = k
  miss_count = 0
  measurement = 0

  while (idx+k) < len(act):
    topic_change_pred = False
    topic_change_act = False

    #Checking if there is a topic change - not including the first index
    if sum(pred[idx-(k-1):idx+k]) >= 1:
      topic_change_pred = True
    if sum(act[idx-(k-1):idx+k]) >= 1:
      topic_change_act = True

    if topic_change_pred != topic_change_act:
      miss_count += 1.0

    measurement += 1.0
    idx += 1

  # print(miss_count)
  # print(measurement)
  pk = miss_count/measurement

  return pk

# evaluate_pk
# Evaluates WD
def evaluate_wd(pred, act, k=5):
  idx = k
  N = len(act)
  count = 0

  while (idx+k) < N:
    # print(pred[idx-(k-1):idx+k])
    sum_pred = sum(pred[idx-(k):idx+k])
    sum_act = sum(act[idx-(k):idx+k])

    #adds a count only if the number of boundaries is greater than 0
    if abs(sum_pred - sum_act) > 0:
      count += 1

    idx += 1

  # print(miss_count)
  # print(measurement)
  wd = (1/(N-k))*count

  return wd

# %%
# Get preds, estimate a threshold for now
preds = rnn_model.predict(X_test)

# Convert preds to binary using threshold
thresh = 0.5
preds_bin = [[1 if x > thresh else 0 for x in p.reshape(-1)] for p in preds]

# Eval PK
pk_metrics = []
wd_metrics = []
for i in range(test_size):
  pk = evaluate_pk(np.array(preds_bin[i]), np.array(y_test[i]), k=int(average_sentences(y_test[i])/2))
  pk_metrics.append(pk)
  wd = evaluate_wd(np.array(preds_bin[i]), np.array(y_test[i]), k=int(average_sentences(y_test[i])/2))
  wd_metrics.append(wd)

print(f"\nThreshold: {thresh}")
print(f"PK Mean: {np.mean(pk_metrics)}")
print(f"WD Mean: {np.mean(wd_metrics)}")

# %%
# # Get threshold for each episode by using mu, sigma of probs
# cos_mus = tf.reduce_mean(preds, axis=0).numpy().reshape(-1)
# cos_sigs = tf.math.reduce_std(preds, axis=0).numpy().reshape(-1)
# ep_thresh = cos_mus + cos_sigs

# # Apply
# preds_bin = np.empty((test_size, max_sequence), dtype=int)
# for i in range(len(preds)):
#   preds_bin[i] = [1 if x > ep_thresh[i] else 0 for x in preds[i].reshape(-1)]

# # Eval PK
# pk_metrics = []
# wd_metrics = []
# for i in range(test_size):
#   pk = evaluate_pk(np.array(preds_bin[i]), np.array(y_test[i]), k=int(average_sentences(y_test[i])/2))
#   pk_metrics.append(pk)xa
#   wd = evaluate_wd(np.array(preds_bin[i]), np.array(y_test[i]), k=int(average_sentences(y_test[i])/2))
#   wd_metrics.append(wd)

# print(f"PK Mean: {np.mean(pk_metrics)}")
# print(f"WD Mean: {np.mean(wd_metrics)}")
